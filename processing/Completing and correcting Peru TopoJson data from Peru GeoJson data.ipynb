# %% [markdown]
# # Completing and correcting Peru TopoJson data from Peru GeoJson data

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# This file is intended to complete the geographical information of Peru given in the file `peru_all_topo.json`, obtained from the line 853 of the file [`datamaps.per.js`](https://raw.githubusercontent.com/markmarkoh/datamaps/master/dist/datamaps.per.js) provided by [DataMaps](http://datamaps.github.io/), with the information of the file `peru_all_geo.json` obtained from the file [`pe-all.geo.json`](http://code.highcharts.com/mapdata/countries/pe/pe-all.geo.json) provided for [HighCharts](http://www.highcharts.com/) and based on data from [Natural Earth](http://www.naturalearthdata.com).

# %% [markdown]
# Before processing and mixing the data some manual tweaks were necessaries. In the file `peru_all_topo.json` the geometry id `PE.LR`, corresponding to Lima where found twice. One corresponding to Lima Provice (FIPS PE26, HASC PE.LP) and the other correspondign to Lima Department (FIPS PE15, HASC PE.LR). There were an error with identification of Callao, that appeared with `id` PE. and PE.CL. Some part of the d¿data is conrresponding to the Constitutional Provice of Callao and the other is for Department of Puno. The same mistake was found in `peru_all_geo.json` which refers to PE.LP and PE.CL as PE.145 and PE.3341. Also some errors in FIPS keys were found. Those all mistakes where corrected usign statoids information provided by http://www.statoids.com/upe.html.
# Keys that not figure in http://www.statoids.com/upe.html were neglected.

# %% [markdown]
# ## 2. Processing

# %% [markdown]
# All the subseqent proccessign make use of python json library in order to load data from json files.

# %%
import json

# %% [markdown]
# ### 2.1 Statoids Data

# %%
statoids = {
    "PE.AM": {
        "name": "Amazonas",
        "hasc": "PE.AM",
        "iso": "AMA",
        "fips": "PE01",
        "nute": 40201
    },
    "PE.AN": {
        "name": "Ancash",
        "hasc": "PE.AN",
        "iso": "ANC",
        "fips": "PE02",
        "nute": 40502
    },
    "PE.AP": {
        "name": "Apurímac",
        "hasc": "PE.AP",
        "iso": "APU",
        "fips": "PE03",
        "nute": 40903
    },
    "PE.AR": {
        "name": "Arequipa",
        "hasc": "PE.AR",
        "iso": "ARE",
        "fips": "PE04",
        "nute": 41004
    },
    "PE.AY": {
        "name": "Ayacucho",
        "hasc": "PE.AY",
        "iso": "AYA",
        "fips": "PE05",
        "nute": 40905
    },
    "PE.CJ": {
        "name": "Cajamarca",
        "hasc": "PE.CJ",
        "iso": "CAJ",
        "fips": "PE06",
        "nute": 40106
    },
    "PE.CL": {
        "name": "Callao",
        "hasc": "PE.CL",
        "iso": "CAL",
        "fips": "PE07",
        "nute": 40607
    },
    "PE.CS": {
        "name": "Cusco",
        "hasc": "PE.CS",
        "iso": "CUS",
        "fips": "PE08",
        "nute": 40808
    },
    "PE.HV": {
        "name": "Huancavelica",
        "hasc": "PE.HV",
        "iso": "HUV",
        "fips": "PE09",
        "nute": 40909
    },
    "PE.HC": {
        "name": "Huánuco",
        "hasc": "PE.HC",
        "iso": "HUC",
        "fips": "PE10",
        "nute": 40410
    },
    "PE.IC": {
        "name": "Ica",
        "hasc": "PE.IC",
        "iso": "ICA",
        "fips": "PE11",
        "nute": 41011
    },
    "PE.JU": {
        "name": "Junín",
        "hasc": "PE.JU",
        "iso": "JUN",
        "fips": "PE12",
        "nute": 40712
    },
    "PE.LL": {
        "name": "La Libertad",
        "hasc": "PE.LL",
        "iso": "LAL",
        "fips": "PE13",
        "nute": 40513
    },
    "PE.LB": {
        "name": "Lambayeque",
        "hasc": "PE.LB",
        "iso": "LAM",
        "fips": "PE14",
        "nute": 40114
    },
    "PE.LP": {
        "name": "Lima Provincia",
        "hasc": "PE.LP",
        "iso": "LMA",
        "fips": "PE26",
        "nute": 40615
    },
    "PE.LR": {
        "name": "Lima",
        "hasc": "PE.LR",
        "iso": "LIM",
        "fips": "PE15",
        "nute": 40615
    },
    "PE.LO": {
        "name": "Loreto",
        "hasc": "PE.LO",
        "iso": "LOR",
        "fips": "PE16",
        "nute": 40316
    },
    "PE.MD": {
        "name": "Madre de Dios",
        "hasc": "PE.MD",
        "iso": "MDD",
        "fips": "PE17",
        "nute": 40817
    },
    "PE.MQ": {
        "name": "Moquegua",
        "hasc": "PE.MQ",
        "iso": "MOQ",
        "fips": "PE18",
        "nute": 41118
    },
    "PE.PA": {
        "name": "Pasco",
        "hasc": "PE.PA",
        "iso": "PAS",
        "fips": "PE19",
        "nute": 40719
    },
    "PE.PI": {
        "name": "Piura",
        "hasc": "PE.PI",
        "iso": "PIU",
        "fips": "PE20",
        "nute": 40120
    },
    "PE.PU": {
        "name": "Puno",
        "hasc": "PE.PU",
        "iso": "PUN",
        "fips": "PE21",
        "nute": 41121
    },
    "PE.SM": {
        "name": "San Martín",
        "hasc": "PE.SM",
        "iso": "SAM",
        "fips": "PE22",
        "nute": 40222
    },
    "PE.TA": {
        "name": "Tacna",
        "hasc": "PE.TA",
        "iso": "TAC",
        "fips": "PE23",
        "nute": 41123
    },
    "PE.TU": {
        "name": "Tumbes",
        "hasc": "PE.TU",
        "iso": "TUM",
        "fips": "PE24",
        "nute": 40124
    },
    "PE.UC": {
        "name": "Ucayali",
        "hasc": "PE.UC",
        "iso": "UCA",
        "fips": "PE25",
        "nute": 40425
    }
}

# %%
properties_list = ["#", "Name", "HASC", "ISO", "FIPS", "NUTE"]
str_template = "{0:2s}  {1:20s}{2:10s}{3:10s}{4:10s}{5:10s}"
print(str_template.format(*properties_list))

statoids_list = list(statoids.items())
statoids_list.sort()

str_template= "{0:0>2d}  {1:20s}{2:10s}{3:10s}{4:10s}{5:10s}"

for i, (id_, properties)  in enumerate(statoids_list):
    properties = list(str(properties[property_name.lower()]) for property_name in properties_list[1:])
    print(str_template.format(i+1, *properties))
# Out:
# #   Name                HASC      ISO       FIPS      NUTE
# 01  Amazonas            PE.AM     AMA       PE01      40201
# 02  Ancash              PE.AN     ANC       PE02      40502
# 03  Apurímac            PE.AP     APU       PE03      40903
# 04  Arequipa            PE.AR     ARE       PE04      41004
# 05  Ayacucho            PE.AY     AYA       PE05      40905
# 06  Cajamarca           PE.CJ     CAJ       PE06      40106
# 07  Callao              PE.CL     CAL       PE07      40607
# 08  Cusco               PE.CS     CUS       PE08      40808
# 09  Huánuco             PE.HC     HUC       PE10      40410
# 10  Huancavelica        PE.HV     HUV       PE09      40909
# 11  Ica                 PE.IC     ICA       PE11      41011
# 12  Junín               PE.JU     JUN       PE12      40712
# 13  Lambayeque          PE.LB     LAM       PE14      40114
# 14  La Libertad         PE.LL     LAL       PE13      40513
# 15  Loreto              PE.LO     LOR       PE16      40316
# 16  Lima Provincia      PE.LP     LMA       PE26      40615
# 17  Lima                PE.LR     LIM       PE15      40615
# 18  Madre de Dios       PE.MD     MDD       PE17      40817
# 19  Moquegua            PE.MQ     MOQ       PE18      41118
# 20  Pasco               PE.PA     PAS       PE19      40719
# 21  Piura               PE.PI     PIU       PE20      40120
# 22  Puno                PE.PU     PUN       PE21      41121
# 23  San Martín          PE.SM     SAM       PE22      40222
# 24  Tacna               PE.TA     TAC       PE23      41123
# 25  Tumbes              PE.TU     TUM       PE24      40124
# 26  Ucayali             PE.UC     UCA       PE25      40425

# %% [markdown]
# ### 2.1 Corrections in GeoJson Data

# %%
# Loading GeoJson Data
geo_file = "./peru_all_geo.json"
geo_handler = open(geo_file, "r")
geo_json = geo_handler.read()
geo_handler.close()
geo_json = json.loads(geo_json)

# %% [markdown]
# Every departament and province in `geoJson` variable is identified as a feature object, every feature object has a property called `properties` which contains metadata of the feature. The list of properties names is

# %%
# Getting names of properties for each feature in 
geo_properties_list = list(geo_json["features"][0]["properties"].keys())
geo_properties_list.sort()

for property_ in geo_properties_list:
    print("*", property_)
# Out:
# * alt-name
# * country
# * fips
# * hasc
# * hc-a2
# * hc-group
# * hc-key
# * hc-middle-x
# * hc-middle-y
# * labelrank
# * latitude
# * longitude
# * name
# * postal-code
# * region
# * subregion
# * type
# * type-en
# * woe-id
# * woe-label
# * woe-name

# %% [markdown]
# Tabulating properties in the same way as satoids

# %%
# Tabulating data of features in geojson
properties_list = ["#", "ID", "Name", "HASC", "ISO", "FIPS", "NUTE"]
str_template = "{0:2s}  {1:10s}{2:20s}{3:10s}{4:10s}{5:10s}{6:10s}"
print(str_template.format(*properties_list))

geo_features = dict((feature["id"], feature["properties"]) for feature in geo_json["features"])

features_list = list(geo_features.items())
features_list.sort()

str_template = "{0:0>2d}  {1:10s}{2:20s}{3:10s}{4:10s}{5:10s}{6:10s}"

for i, (id_, property_) in enumerate(features_list):
    
    property_ = list(
        str(property_[pn.lower()]) if pn.lower() in property_.keys() else "---" for pn in properties_list[2:]
    )
    
    print(
        str_template.format(
            i + 1,
            id_,
            *property_
        )
    )
# Out:
# #   ID        Name                HASC      ISO       FIPS      NUTE
# 01  PE.145    Lima Province       PE.LR     ---       None      ---
# 02  PE.3341   Callao              PE.       ---       None      ---
# 03  PE.AM     Amazonas            PE.AM     ---       PE01      ---
# 04  PE.AN     Ancash              PE.AN     ---       PE02      ---
# 05  PE.AP     Apurímac            PE.AP     ---       PE03      ---
# 06  PE.AR     Arequipa            PE.AR     ---       PE04      ---
# 07  PE.AY     Ayacucho            PE.AY     ---       PE09      ---
# 08  PE.CJ     Cajamarca           PE.CJ     ---       PE06      ---
# 09  PE.CL     Callao              PE.CL     ---       PE21      ---
# 10  PE.CS     Cusco               PE.CS     ---       PE08      ---
# 11  PE.HC     Huánuco             PE.HC     ---       PE10      ---
# 12  PE.HV     Huancavelica        PE.HV     ---       PE09      ---
# 13  PE.IC     Ica                 PE.IC     ---       PE11      ---
# 14  PE.JU     Junín               PE.JU     ---       PE12      ---
# 15  PE.LB     Lambayeque          PE.LB     ---       PE14      ---
# 16  PE.LL     La Libertad         PE.LL     ---       PE13      ---
# 17  PE.LO     Loreto              PE.LO     ---       PE16      ---
# 18  PE.LR     Lima                PE.LR     ---       PE15      ---
# 19  PE.MD     Madre de Dios       PE.MD     ---       PE17      ---
# 20  PE.MQ     Moquegua            PE.MQ     ---       PE18      ---
# 21  PE.PA     Pasco               PE.PA     ---       PE19      ---
# 22  PE.PI     Piura               PE.PI     ---       PE20      ---
# 23  PE.SM     San Martín          PE.SM     ---       PE22      ---
# 24  PE.TA     Tacna               PE.TA     ---       PE23      ---
# 25  PE.TU     Tumbes              PE.TU     ---       PE24      ---
# 26  PE.UC     Ucayali             PE.UC     ---       PE25      ---

# %% [markdown]
# As is seen in the above list, HASC codes doesn't match with feature id for PE.145 and PE.3341. Also HASC code is repeated for PE.145 and PE.LR, and name Callao appear twice in PE.3341 and PE.CL. This fact give us a reazon to analze more in deepth the features with id PE.145, PE.3341, PE.CL and PE.LR.

# %% [markdown]
# In the following cells of code the data will be analized and corrected

# %%
features_list = list(geo_features.items())
features_list.sort();

unused_features_id_list = list(geo_features.keys())
unused_statoids_id_list = list(statoids.keys())

for id_, properties in features_list:
    print("+ ID: {0:} ... ".format(id_), end="")
    
    if id_ in unused_statoids_id_list:
        statoids_properties = statoids[id_]
        
        geo_features[id_].update(statoids_properties)
        properties.update(statoids_properties)
        
        unused_features_id_list.remove(id_)
        unused_statoids_id_list.remove(id_)
        
        print("Updated")
        
    else:
        print("Not registered")
        
        
    properties = list(properties.items())
    properties.sort()
    
    for name, value in properties:
        print("  - {0:15s}: {1:20s}".format(name, str(value)))
    
    print("\n")
# Out:
# + ID: PE.145 ... Not registered
#   - alt-name       : Federal capital
#   - country        : Peru
#   - fips           : None
#   - hasc           : PE.LR
#   - hc-a2          : LP
#   - hc-group       : admin1
#   - hc-key         : pe-145
#   - hc-middle-x    : 0.33
#   - hc-middle-y    : 0.33
#   - labelrank      : 9
#   - latitude       : -12.1124
#   - longitude      : -76.92359999999999
#   - name           : Lima Province
#   - postal-code    : None
#   - region         : None
#   - subregion      : None
#   - type           : Distrito Capital
#   - type-en        : Captial District
#   - woe-id         : 28358302
#   - woe-label      : Lima Metropolitan Area, PE, Peru
#   - woe-name       : Lima Province
#
#
# + ID: PE.3341 ... Not registered
#   - alt-name       : Region
#   - country        : Peru
#   - fips           : None
#   - hasc           : PE.
#   - hc-a2          : CA
#   - hc-group       : admin1
#   - hc-key         : pe-3341
#   - hc-middle-x    : 0.58
#   - hc-middle-y    : 0.48
#   - labelrank      : 9
#   - latitude       : -12.0859
#   - longitude      : -77.2248
#   - name           : Callao
#   - postal-code    : None
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Departamento
#   - woe-id         : 2346474
#   - woe-label      : Provincia Constitucional del Callao, PE, Peru
#   - woe-name       : Callao
#
#
# + ID: PE.AM ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE01
#   - hasc           : PE.AM
#   - hc-a2          : AM
#   - hc-group       : admin1
#   - hc-key         : pe-am
#   - hc-middle-x    : 0.38
#   - hc-middle-y    : 0.48
#   - iso            : AMA
#   - labelrank      : 4
#   - latitude       : -5.0485
#   - longitude      : -77.9695
#   - name           : Amazonas
#   - nute           : 40201
#   - postal-code    : AM
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346468
#   - woe-label      : Amazonas, PE, Peru
#   - woe-name       : Amazonas
#
#
# + ID: PE.AN ... Updated
#   - alt-name       : Ancachs
#   - country        : Peru
#   - fips           : PE02
#   - hasc           : PE.AN
#   - hc-a2          : AN
#   - hc-group       : admin1
#   - hc-key         : pe-an
#   - hc-middle-x    : 0.56
#   - hc-middle-y    : 0.56
#   - iso            : ANC
#   - labelrank      : 4
#   - latitude       : -9.539960000000001
#   - longitude      : -77.6571
#   - name           : Ancash
#   - nute           : 40502
#   - postal-code    : AN
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346469
#   - woe-label      : Ancash, PE, Peru
#   - woe-name       : Ancash
#
#
# + ID: PE.AP ... Updated
#   - alt-name       : Apuromac
#   - country        : Peru
#   - fips           : PE03
#   - hasc           : PE.AP
#   - hc-a2          : AP
#   - hc-group       : admin1
#   - hc-key         : pe-ap
#   - hc-middle-x    : 0.53
#   - hc-middle-y    : 0.55
#   - iso            : APU
#   - labelrank      : 4
#   - latitude       : -14.0317
#   - longitude      : -72.9662
#   - name           : Apurímac
#   - nute           : 40903
#   - postal-code    : AP
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346470
#   - woe-label      : Apurímac, PE, Peru
#   - woe-name       : Apurímac
#
#
# + ID: PE.AR ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE04
#   - hasc           : PE.AR
#   - hc-a2          : AR
#   - hc-group       : admin1
#   - hc-key         : pe-ar
#   - hc-middle-x    : 0.68
#   - hc-middle-y    : 0.49
#   - iso            : ARE
#   - labelrank      : 6
#   - latitude       : -15.8757
#   - longitude      : -72.4209
#   - name           : Arequipa
#   - nute           : 41004
#   - postal-code    : AR
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346471
#   - woe-label      : Arequipa, PE, Peru
#   - woe-name       : Arequipa
#
#
# + ID: PE.AY ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE05
#   - hasc           : PE.AY
#   - hc-a2          : AY
#   - hc-group       : admin1
#   - hc-key         : pe-ay
#   - hc-middle-x    : 0.41
#   - hc-middle-y    : 0.57
#   - iso            : AYA
#   - labelrank      : 7
#   - latitude       : -13.9245
#   - longitude      : -73.9838
#   - name           : Ayacucho
#   - nute           : 40905
#   - postal-code    : AY
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346472
#   - woe-label      : Ayacucho, PE, Peru
#   - woe-name       : Ayacucho
#
#
# + ID: PE.CJ ... Updated
#   - alt-name       : Caxamarca
#   - country        : Peru
#   - fips           : PE06
#   - hasc           : PE.CJ
#   - hc-a2          : CJ
#   - hc-group       : admin1
#   - hc-key         : pe-cj
#   - hc-middle-x    : 0.51
#   - hc-middle-y    : 0.71
#   - iso            : CAJ
#   - labelrank      : 7
#   - latitude       : -6.81775
#   - longitude      : -78.6091
#   - name           : Cajamarca
#   - nute           : 40106
#   - postal-code    : CJ
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346473
#   - woe-label      : Cajamarca, PE, Peru
#   - woe-name       : Cajamarca
#
#
# + ID: PE.CL ... Updated
#   - alt-name       : El Callao
#   - country        : Peru
#   - fips           : PE07
#   - hasc           : PE.CL
#   - hc-a2          : CL
#   - hc-group       : admin1
#   - hc-key         : pe-cl
#   - hc-middle-x    : 0.46
#   - hc-middle-y    : 0.41
#   - iso            : CAL
#   - labelrank      : 4
#   - latitude       : -15.1677
#   - longitude      : -69.9802
#   - name           : Callao
#   - nute           : 40607
#   - postal-code    : CL
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346488
#   - woe-label      : Puno, PE, Peru
#   - woe-name       : Callao
#
#
# + ID: PE.CS ... Updated
#   - alt-name       : Cuzco|Qosqo
#   - country        : Peru
#   - fips           : PE08
#   - hasc           : PE.CS
#   - hc-a2          : CS
#   - hc-group       : admin1
#   - hc-key         : pe-cs
#   - hc-middle-x    : 0.52
#   - hc-middle-y    : 0.49
#   - iso            : CUS
#   - labelrank      : 6
#   - latitude       : -13.1633
#   - longitude      : -72.2479
#   - name           : Cusco
#   - nute           : 40808
#   - postal-code    : CS
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346475
#   - woe-label      : Cusco, PE, Peru
#   - woe-name       : Cusco
#
#
# + ID: PE.HC ... Updated
#   - alt-name       : Huknuco
#   - country        : Peru
#   - fips           : PE10
#   - hasc           : PE.HC
#   - hc-a2          : HC
#   - hc-group       : admin1
#   - hc-key         : pe-hc
#   - hc-middle-x    : 0.34
#   - hc-middle-y    : 0.5
#   - iso            : HUC
#   - labelrank      : 7
#   - latitude       : -9.592029999999999
#   - longitude      : -75.9161
#   - name           : Huánuco
#   - nute           : 40410
#   - postal-code    : HC
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346477
#   - woe-label      : Huánuco, PE, Peru
#   - woe-name       : Huánuco
#
#
# + ID: PE.HV ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE09
#   - hasc           : PE.HV
#   - hc-a2          : HV
#   - hc-group       : admin1
#   - hc-key         : pe-hv
#   - hc-middle-x    : 0.54
#   - hc-middle-y    : 0.48
#   - iso            : HUV
#   - labelrank      : 7
#   - latitude       : -13.0523
#   - longitude      : -75.0416
#   - name           : Huancavelica
#   - nute           : 40909
#   - postal-code    : HV
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346476
#   - woe-label      : Huancavelica, PE, Peru
#   - woe-name       : Huancavelica
#
#
# + ID: PE.IC ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE11
#   - hasc           : PE.IC
#   - hc-a2          : IC
#   - hc-group       : admin1
#   - hc-key         : pe-ic
#   - hc-middle-x    : 0.49
#   - hc-middle-y    : 0.52
#   - iso            : ICA
#   - labelrank      : 7
#   - latitude       : -14.2257
#   - longitude      : -75.6773
#   - name           : Ica
#   - nute           : 41011
#   - postal-code    : IC
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346478
#   - woe-label      : Ica, PE, Peru
#   - woe-name       : Ica
#
#
# + ID: PE.JU ... Updated
#   - alt-name       : Junnn
#   - country        : Peru
#   - fips           : PE12
#   - hasc           : PE.JU
#   - hc-a2          : JU
#   - hc-group       : admin1
#   - hc-key         : pe-ju
#   - hc-middle-x    : 0.53
#   - hc-middle-y    : 0.43
#   - iso            : JUN
#   - labelrank      : 4
#   - latitude       : -11.3744
#   - longitude      : -74.96420000000001
#   - name           : Junín
#   - nute           : 40712
#   - postal-code    : JU
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346479
#   - woe-label      : Junín, PE, Peru
#   - woe-name       : Junín
#
#
# + ID: PE.LB ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE14
#   - hasc           : PE.LB
#   - hc-a2          : LB
#   - hc-group       : admin1
#   - hc-key         : pe-lb
#   - hc-middle-x    : 0.52
#   - hc-middle-y    : 0.44
#   - iso            : LAM
#   - labelrank      : 4
#   - latitude       : -6.2514
#   - longitude      : -79.8994
#   - name           : Lambayeque
#   - nute           : 40114
#   - postal-code    : LB
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346481
#   - woe-label      : Lambayeque, PE, Peru
#   - woe-name       : Lambayeque
#
#
# + ID: PE.LL ... Updated
#   - alt-name       : Libertad
#   - country        : Peru
#   - fips           : PE13
#   - hasc           : PE.LL
#   - hc-a2          : LL
#   - hc-group       : admin1
#   - hc-key         : pe-ll
#   - hc-middle-x    : 0.4
#   - hc-middle-y    : 0.57
#   - iso            : LAL
#   - labelrank      : 4
#   - latitude       : -8.213340000000001
#   - longitude      : -78.2813
#   - name           : La Libertad
#   - nute           : 40513
#   - postal-code    : LL
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346480
#   - woe-label      : La Libertad, PE, Peru
#   - woe-name       : La Libertad
#
#
# + ID: PE.LO ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE16
#   - hasc           : PE.LO
#   - hc-a2          : LO
#   - hc-group       : admin1
#   - hc-key         : pe-lo
#   - hc-middle-x    : 0.38
#   - hc-middle-y    : 0.48
#   - iso            : LOR
#   - labelrank      : 4
#   - latitude       : -4.27471
#   - longitude      : -73.88679999999999
#   - name           : Loreto
#   - nute           : 40316
#   - postal-code    : LO
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346483
#   - woe-label      : Loreto, PE, Peru
#   - woe-name       : Loreto
#
#
# + ID: PE.LR ... Updated
#   - alt-name       : Lima province
#   - country        : Peru
#   - fips           : PE15
#   - hasc           : PE.LR
#   - hc-a2          : LR
#   - hc-group       : admin1
#   - hc-key         : pe-lr
#   - hc-middle-x    : 0.39
#   - hc-middle-y    : 0.37
#   - iso            : LIM
#   - labelrank      : 4
#   - latitude       : -11.0602
#   - longitude      : -77.07559999999999
#   - name           : Lima
#   - nute           : 40615
#   - postal-code    : LR
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346482
#   - woe-label      : Lima, PE, Peru
#   - woe-name       : Lima
#
#
# + ID: PE.MD ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE17
#   - hasc           : PE.MD
#   - hc-a2          : MD
#   - hc-group       : admin1
#   - hc-key         : pe-md
#   - hc-middle-x    : 0.47
#   - hc-middle-y    : 0.58
#   - iso            : MDD
#   - labelrank      : 4
#   - latitude       : -11.8726
#   - longitude      : -70.6831
#   - name           : Madre de Dios
#   - nute           : 40817
#   - postal-code    : MD
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346484
#   - woe-label      : Madre de Dios, PE, Peru
#   - woe-name       : Madre de Dios
#
#
# + ID: PE.MQ ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE18
#   - hasc           : PE.MQ
#   - hc-a2          : MQ
#   - hc-group       : admin1
#   - hc-key         : pe-mq
#   - hc-middle-x    : 0.49
#   - hc-middle-y    : 0.42
#   - iso            : MOQ
#   - labelrank      : 7
#   - latitude       : -16.6807
#   - longitude      : -70.7546
#   - name           : Moquegua
#   - nute           : 41118
#   - postal-code    : MQ
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346485
#   - woe-label      : Moquegua, PE, Peru
#   - woe-name       : Moquegua
#
#
# + ID: PE.PA ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE19
#   - hasc           : PE.PA
#   - hc-a2          : PA
#   - hc-group       : admin1
#   - hc-key         : pe-pa
#   - hc-middle-x    : 0.61
#   - hc-middle-y    : 0.43
#   - iso            : PAS
#   - labelrank      : 7
#   - latitude       : -10.3457
#   - longitude      : -75.4586
#   - name           : Pasco
#   - nute           : 40719
#   - postal-code    : PA
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346486
#   - woe-label      : Pasco, PE, Peru
#   - woe-name       : Pasco
#
#
# + ID: PE.PI ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE20
#   - hasc           : PE.PI
#   - hc-a2          : PI
#   - hc-group       : admin1
#   - hc-key         : pe-pi
#   - hc-middle-x    : 0.55
#   - hc-middle-y    : 0.46
#   - iso            : PIU
#   - labelrank      : 7
#   - latitude       : -5.09955
#   - longitude      : -80.2868
#   - name           : Piura
#   - nute           : 40120
#   - postal-code    : PI
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346487
#   - woe-label      : Piura, PE, Peru
#   - woe-name       : Piura
#
#
# + ID: PE.SM ... Updated
#   - alt-name       : San Mart
#   - country        : Peru
#   - fips           : PE22
#   - hasc           : PE.SM
#   - hc-a2          : SM
#   - hc-group       : admin1
#   - hc-key         : pe-sm
#   - hc-middle-x    : 0.4
#   - hc-middle-y    : 0.6
#   - iso            : SAM
#   - labelrank      : 4
#   - latitude       : -7.30853
#   - longitude      : -76.6238
#   - name           : San Martín
#   - nute           : 40222
#   - postal-code    : SM
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346489
#   - woe-label      : San Martin, PE, Peru
#   - woe-name       : San Martín
#
#
# + ID: PE.TA ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE23
#   - hasc           : PE.TA
#   - hc-a2          : TA
#   - hc-group       : admin1
#   - hc-key         : pe-ta
#   - hc-middle-x    : 0.55
#   - hc-middle-y    : 0.54
#   - iso            : TAC
#   - labelrank      : 7
#   - latitude       : -17.5742
#   - longitude      : -70.34229999999999
#   - name           : Tacna
#   - nute           : 41123
#   - postal-code    : TA
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346490
#   - woe-label      : Tacna, PE, Peru
#   - woe-name       : Tacna
#
#
# + ID: PE.TU ... Updated
#   - alt-name       : Tumbez
#   - country        : Peru
#   - fips           : PE24
#   - hasc           : PE.TU
#   - hc-a2          : TU
#   - hc-group       : admin1
#   - hc-key         : pe-tu
#   - hc-middle-x    : 0.56
#   - hc-middle-y    : 0.59
#   - iso            : TUM
#   - labelrank      : 7
#   - latitude       : -3.88493
#   - longitude      : -80.6135
#   - name           : Tumbes
#   - nute           : 40124
#   - postal-code    : TU
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346491
#   - woe-label      : Tumbes, PE, Peru
#   - woe-name       : Tumbes
#
#
# + ID: PE.UC ... Updated
#   - alt-name       : None
#   - country        : Peru
#   - fips           : PE25
#   - hasc           : PE.UC
#   - hc-a2          : UC
#   - hc-group       : admin1
#   - hc-key         : pe-uc
#   - hc-middle-x    : 0.59
#   - hc-middle-y    : 0.79
#   - iso            : UCA
#   - labelrank      : 4
#   - latitude       : -9.99816
#   - longitude      : -73.24930000000001
#   - name           : Ucayali
#   - nute           : 40425
#   - postal-code    : UC
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346492
#   - woe-label      : Ucayali, PE, Peru
#   - woe-name       : Ucayali

# %% [markdown]
# in the previous block is seen that some ID are unused and are stored in `unused_` lists. Thos ID are potential errors and can reveal other errors

# %%
print("Unused features IDs:", unused_features_id_list)
print("Unused statoids IDs:", unused_statoids_id_list)
# Out:
# Unused features IDs: ['PE.3341', 'PE.145']
# Unused statoids IDs: ['PE.LP', 'PE.PU']

# %% [markdown]
# As is seen, statoids doesn't have ids 'PE.3341' nor 'PE.145', and the ids both 'PE.PU' and 'PE.LP' are not registered in features of geojson, those data need to be compared

# %%
properties_list = ["type","ID", "Name", "HASC", "FIPS"]
str_template = "{0:10s}{1:10s}{2:20s}{3:10s}{4:10s}"

print(str_template.format(*properties_list))

for id_ in unused_features_id_list:
    print(
        str_template.format(
            "feature",
            id_, 
            *list(str(geo_features[id_][property_name.lower()]) for property_name in properties_list[2:])
        )
    )

for id_ in unused_statoids_id_list:
    print(
        str_template.format(
            "statoid",
            id_, 
            *list(str(statoids[id_][property_name.lower()]) for property_name in properties_list[2:])
        )
    )
# Out:
# type      ID        Name                HASC      FIPS
# feature   PE.3341   Callao              PE.       None
# feature   PE.145    Lima Province       PE.LR     None
# statoid   PE.LP     Lima Provincia      PE.LP     PE26
# statoid   PE.PU     Puno                PE.PU     PE21

# %% [markdown]
# The code above reveals that Callao, needs to be analized in both features and statoids. In order to complete the list of keys that was previously deduced, is necessary add tho this analisys the PE.LR key.

# %%
warn_features_id_list = unused_features_id_list
warn_features_id_list.append('PE.CL')
warn_features_id_list.append('PE.LR')
warn_features_id_list.sort()

warn_statoids_id_list = unused_statoids_id_list
warn_statoids_id_list.append('PE.CL')
warn_statoids_id_list.append('PE.LR')
warn_statoids_id_list.sort()

properties_list = ["type","ID", "Name", "HASC", "FIPS"]
str_template = "{0:10s}{1:10s}{2:20s}{3:10s}{4:10s}"

print(str_template.format(*properties_list))

for id_ in warn_features_id_list:
    print(
        str_template.format(
            "feature",
            id_, 
            *list(str(geo_features[id_][property_name.lower()]) for property_name in properties_list[2:])
        )
    )

for id_ in warn_statoids_id_list:
    print(
        str_template.format(
            "statoid",
            id_, 
            *list(str(statoids[id_][property_name.lower()]) for property_name in properties_list[2:])
        )
    )
# Out:
# type      ID        Name                HASC      FIPS
# feature   PE.145    Lima Province       PE.LR     None
# feature   PE.3341   Callao              PE.       None
# feature   PE.CL     Callao              PE.CL     PE07
# feature   PE.LR     Lima                PE.LR     PE15
# statoid   PE.CL     Callao              PE.CL     PE07
# statoid   PE.LP     Lima Provincia      PE.LP     PE26
# statoid   PE.LR     Lima                PE.LR     PE15
# statoid   PE.PU     Puno                PE.PU     PE21

# %% [markdown]
# The HASC code of Lima Provice is wrong, Callao is twice referenced, and Puno is not referenced.

# %%
features_list = list((id_,geo_features[id_]) for id_ in unused_features_id_list)
features_list.sort();

for id_, properties in features_list:
    print("+ ID: {0:}".format(id_))
        
    properties = list(properties.items())
    properties.sort()
    
    for name, value in properties:
        print("  - {0:15s}: {1:20s}".format(name, str(value)))
    
    print("\n")
# Out:
# + ID: PE.145
#   - alt-name       : Federal capital
#   - country        : Peru
#   - fips           : None
#   - hasc           : PE.LR
#   - hc-a2          : LP
#   - hc-group       : admin1
#   - hc-key         : pe-145
#   - hc-middle-x    : 0.33
#   - hc-middle-y    : 0.33
#   - labelrank      : 9
#   - latitude       : -12.1124
#   - longitude      : -76.92359999999999
#   - name           : Lima Province
#   - postal-code    : None
#   - region         : None
#   - subregion      : None
#   - type           : Distrito Capital
#   - type-en        : Captial District
#   - woe-id         : 28358302
#   - woe-label      : Lima Metropolitan Area, PE, Peru
#   - woe-name       : Lima Province
#
#
# + ID: PE.3341
#   - alt-name       : Region
#   - country        : Peru
#   - fips           : None
#   - hasc           : PE.
#   - hc-a2          : CA
#   - hc-group       : admin1
#   - hc-key         : pe-3341
#   - hc-middle-x    : 0.58
#   - hc-middle-y    : 0.48
#   - labelrank      : 9
#   - latitude       : -12.0859
#   - longitude      : -77.2248
#   - name           : Callao
#   - postal-code    : None
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Departamento
#   - woe-id         : 2346474
#   - woe-label      : Provincia Constitucional del Callao, PE, Peru
#   - woe-name       : Callao
#
#
# + ID: PE.CL
#   - alt-name       : El Callao
#   - country        : Peru
#   - fips           : PE07
#   - hasc           : PE.CL
#   - hc-a2          : CL
#   - hc-group       : admin1
#   - hc-key         : pe-cl
#   - hc-middle-x    : 0.46
#   - hc-middle-y    : 0.41
#   - iso            : CAL
#   - labelrank      : 4
#   - latitude       : -15.1677
#   - longitude      : -69.9802
#   - name           : Callao
#   - nute           : 40607
#   - postal-code    : CL
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346488
#   - woe-label      : Puno, PE, Peru
#   - woe-name       : Callao
#
#
# + ID: PE.LR
#   - alt-name       : Lima province
#   - country        : Peru
#   - fips           : PE15
#   - hasc           : PE.LR
#   - hc-a2          : LR
#   - hc-group       : admin1
#   - hc-key         : pe-lr
#   - hc-middle-x    : 0.39
#   - hc-middle-y    : 0.37
#   - iso            : LIM
#   - labelrank      : 4
#   - latitude       : -11.0602
#   - longitude      : -77.07559999999999
#   - name           : Lima
#   - nute           : 40615
#   - postal-code    : LR
#   - region         : None
#   - subregion      : None
#   - type           : Departamento
#   - type-en        : Department
#   - woe-id         : 2346482
#   - woe-label      : Lima, PE, Peru
#   - woe-name       : Lima

# %% [markdown]
# #### 2.1.1 Correction for PE.145

# %%
geo_features['PE.145']["alt-name"] = "Lima Metropolitana"
geo_features['PE.145']["country"] = "Peru"
geo_features['PE.145']["fips"] = None
geo_features['PE.145']["hasc"] = "PE.LP"
geo_features['PE.145']["hc-a2"] = "LP"
geo_features['PE.145']["hc-group"] = "admin1"
geo_features['PE.145']["hc-key"] = "pe-lp"
geo_features['PE.145']["hc-middle-x"] = 0.33
geo_features['PE.145']["hc-middle-y"] = 0.33
geo_features['PE.145']["labelrank"] = 9
geo_features['PE.145']["latitude"] = -12.1124
geo_features['PE.145']["longitude"] = -76.92359999999999
geo_features['PE.145']["name"] = "Lima Province"
geo_features['PE.145']["postal-code"] = None
geo_features['PE.145']["region"] = None
geo_features['PE.145']["subregion"] = None
geo_features['PE.145']["type"] = "Distrito Capital"
geo_features['PE.145']["type-en"] = "Captial District"
geo_features['PE.145']["woe-id"] = 28358302
geo_features['PE.145']["woe-label"] = "Área Metropolitanan de Lima, PE, Peru"
geo_features['PE.145']["woe-name"] = "Lima Provincia"
geo_features.update({'PE.LP':geo_features['PE.145']})
geo_features['PE.LP'].update(statoids['PE.LP'])
geo_features['PE.145'].update(statoids['PE.LP'])

# %% [markdown]
# #### 2.1.2 Addition of PE.PU as replace of PE.CL

# %%
geo_features["PE.CL"]["alt-name"] = "Puno"
geo_features["PE.CL"]["country"] = "Peru"
geo_features["PE.CL"]["fips"] = "PE07"
geo_features["PE.CL"]["hasc"] = "PE.PU"
geo_features["PE.CL"]["hc-a2"] = "PU"
geo_features["PE.CL"]["hc-group"] = "admin1"
geo_features["PE.CL"]["hc-key" ] = "pe-pu"
geo_features["PE.CL"]["hc-middle-x"] = 0.46
geo_features["PE.CL"]["hc-middle-y"] = 0.41
geo_features["PE.CL"]["iso"] = "CAL"
geo_features["PE.CL"]["labelrank"] = 4
geo_features["PE.CL"]["latitude"] = -15.1677
geo_features["PE.CL"]["longitude"] = -69.9802
geo_features["PE.CL"]["name"] = "Puno"
geo_features["PE.CL"]["nute"] = 40607
geo_features["PE.CL"]["postal-code"] = "PU"
geo_features["PE.CL"]["region"] = None
geo_features["PE.CL"]["subregion"] = None
geo_features["PE.CL"]["type"] = "Departamento"
geo_features["PE.CL"]["type-en"] = "Department"
geo_features["PE.CL"]["woe-id"] = 2346488
geo_features["PE.CL"]["woe-label"] = "Puno, PE, Peru"
geo_features["PE.CL"]["woe-name"] = "Puno"
geo_features.update({'PE.PU':geo_features['PE.CL']})
geo_features['PE.PU'].update(statoids['PE.PU'])

# %% [markdown]
# #### 2.1.3 Filling of PE.CL with PE.3341

# %%
geo_features["PE.CL"] = geo_features["PE.3341"]
geo_features["PE.CL"].update(statoids['PE.CL'])
geo_features["PE.3341"].update(statoids['PE.CL'])

# %% [markdown]
# #### 2.1.4 Making corrections in `geo_json` data

# %%
for i, feature in enumerate(geo_json["features"]):
    if feature['id'] == "PE.145":
        geo_json["features"][i]["properties"] = geo_features["PE.145"]
        geo_json["features"][i]["id"] = "PE.LP"
        
    elif feature['id'] == "PE.CL":
        geo_json["features"][i]["properties"] = geo_features["PE.PU"]
        geo_json["features"][i]["id"] = "PE.PU"
        
    elif feature['id'] == "PE.3341":
        geo_json["features"][i]["properties"] = geo_features["PE.CL"]
        geo_json["features"][i]["id"] = "PE.CL"
    
    else:
        geo_json["features"][i]["properties"] = geo_features[feature["id"]]

# %%
properties_list = ["#", "ID", "Name", "HASC", "ISO", "FIPS", "NUTE"]
str_template = "{0:2s}  {1:10s}{2:20s}{3:10s}{4:10s}{5:10s}{6:10s}"
print(str_template.format(*properties_list))

corrected_geo_features = dict((feature["id"], feature["properties"]) for feature in geo_json["features"])

features_list = list(corrected_geo_features.items())
features_list.sort()

str_template = "{0:0>2d}  {1:10s}{2:20s}{3:10s}{4:10s}{5:10s}{6:10s}"

for i, (id_, property_) in enumerate(features_list):
    
    property_ = list(
        str(property_[pn.lower()]) if pn.lower() in property_.keys() else "---" for pn in properties_list[2:]
    )
    
    print(
        str_template.format(
            i + 1,
            id_,
            *property_
        )
    )
# Out:
# #   ID        Name                HASC      ISO       FIPS      NUTE
# 01  PE.AM     Amazonas            PE.AM     AMA       PE01      40201
# 02  PE.AN     Ancash              PE.AN     ANC       PE02      40502
# 03  PE.AP     Apurímac            PE.AP     APU       PE03      40903
# 04  PE.AR     Arequipa            PE.AR     ARE       PE04      41004
# 05  PE.AY     Ayacucho            PE.AY     AYA       PE05      40905
# 06  PE.CJ     Cajamarca           PE.CJ     CAJ       PE06      40106
# 07  PE.CL     Callao              PE.CL     CAL       PE07      40607
# 08  PE.CS     Cusco               PE.CS     CUS       PE08      40808
# 09  PE.HC     Huánuco             PE.HC     HUC       PE10      40410
# 10  PE.HV     Huancavelica        PE.HV     HUV       PE09      40909
# 11  PE.IC     Ica                 PE.IC     ICA       PE11      41011
# 12  PE.JU     Junín               PE.JU     JUN       PE12      40712
# 13  PE.LB     Lambayeque          PE.LB     LAM       PE14      40114
# 14  PE.LL     La Libertad         PE.LL     LAL       PE13      40513
# 15  PE.LO     Loreto              PE.LO     LOR       PE16      40316
# 16  PE.LP     Lima Provincia      PE.LP     LMA       PE26      40615
# 17  PE.LR     Lima                PE.LR     LIM       PE15      40615
# 18  PE.MD     Madre de Dios       PE.MD     MDD       PE17      40817
# 19  PE.MQ     Moquegua            PE.MQ     MOQ       PE18      41118
# 20  PE.PA     Pasco               PE.PA     PAS       PE19      40719
# 21  PE.PI     Piura               PE.PI     PIU       PE20      40120
# 22  PE.PU     Puno                PE.PU     PUN       PE21      41121
# 23  PE.SM     San Martín          PE.SM     SAM       PE22      40222
# 24  PE.TA     Tacna               PE.TA     TAC       PE23      41123
# 25  PE.TU     Tumbes              PE.TU     TUM       PE24      40124
# 26  PE.UC     Ucayali             PE.UC     UCA       PE25      40425

# %% [markdown]
# #### 2.1.5 Saving `geo_json` data

# %%
geo_json = json.dumps(geo_json, indent=4)
geo_json = geo_json.strip('"')
geo_json = geo_json.replace('\\n', '\n')
geo_json = geo_json.replace('\\"', '"')
geo_json = geo_json + '\n'
print(geo_json)

geo_file = "./peru_geo.json"
geo_handler = open(geo_file, "w")
geo_handler.write(geo_json.encode('UTF-8').decode('UTF-8'))
geo_handler.close()
# Out:
# {
#     "title": "Peru",
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {
#                 "woe-name": "Ica",
#                 "hasc": "PE.IC",
#                 "iso": "ICA",
#                 "hc-middle-y": 0.52,
#                 "alt-name": null,
#                 "hc-middle-x": 0.49,
#                 "woe-id": "2346478",
#                 "longitude": "-75.6773",
#                 "subregion": null,
#                 "hc-group": "admin1",
#                 "nute": 41011,
#                 "type": "Departamento",
#                 "region": null,
#                 "hc-key": "pe-ic",
#                 "labelrank": "7",
#                 "hc-a2": "IC",
#                 "fips": "PE11",
#                 "type-en": "Department",
#                 "name": "Ica",
#                 "woe-label": "Ica, PE, Peru",
#                 "postal-code": "IC",
#                 "country": "Peru",
#                 "latitude": "-14.2257"
#             },
#             "id": "PE.IC",
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             2694,
#                             761
#                         ],
#                         [
#                             2629,
#                             808
#                         ],
#                         [
#                             2642,
#                             836
#                         ],
#                         [
#                             2587,
#                             872
#                         ],
#                         [
#                             2600,
#                             898
#                         ],
#                         [
#                             2531,
#                             934
#                         ],
#                         [
#                             2477,
#                             1021
#                         ],
#                         [
#                             2423,
#                             1088
#                         ],
#                         [
#                             2257,
#                             1182
#                         ],
#                         [
#                             2205,
#                             1227
#                         ],
#                         [
#                             2203,
#                             1268
#                         ],
#                         [
#                             2176,
#                             1338
#                         ],
#                         [
#                             2082,
#                             1417
#                         ],
#                         [
#                             2103,
#                             1430
#                         ],
#                         [
#                             2079,
#                             1478
#                         ],
#                         [
#                             2021,
#                             1523
#                         ],
#                         [
#                             2009,
#                             1492
#                         ],
#                         [
#                             1997,
#                             1563
#                         ],
#                         [
#                             2005,
#                             1643
#                         ],
#                         [
#                             1938,
#                             1665
#                         ],
#                         [
#                             1956,
#                             1727
#                         ],
#                         [
#                             1994,
#                             1732
#                         ],
#                         [
#                             2014,
#                             1692
#                         ],
#                         [
#                             2060,
#                             1882
#                         ],
#                         [
#                             2037,
#                             1990
#                         ],
#                         [
#                             2021,
#                             2011
#                         ],
#                         [
#                             2083,
#                             2091
#                         ],
#                         [
#                             2166,
#                             2159
#                         ],
#                         [
#                             2196,
#                             2201
#                         ],
#                         [
#                             2243,
#                             2182
#                         ],
#                         [
#                             2337,
#                             2191
#                         ],
#                         [
#                             2376,
#                             2211
#                         ],
#                         [
#                             2373,
#                             2176
#                         ],
#                         [
#                             2330,
#                             2136
#                         ],
#                         [
#                             2336,
#                             2073
#                         ],
#                         [
#                             2307,
#                             2048
#                         ],
#                         [
#                             2280,
#                             1971
#                         ],
#                         [
#                             2354,
#                             1960
#                         ],
#                         [
#                             2463,
#                             1925
#                         ],
#                         [
#                             2426,
#                             1856
#                         ],
#                         [
#                             2445,
#                             1803
#                         ],
#                         [
#                             2418,
#                             1758
#                         ],
#                         [
#                             2441,
#                             1670
#                         ],
#                         [
#                             2540,
#                             1632
#                         ],
#                         [
#                             2620,
#                             1565
#                         ],
#                         [
#                             2669,
#                             1556
#                         ],
#                         [
#                             2702,
#                             1525
#                         ],
#                         [
#                             2705,
#                             1456
#                         ],
#                         [
#                             2664,
#                             1374
#                         ],
#                         [
#                             2712,
#                             1314
#                         ],
#                         [
#                             2709,
#                             1251
#                         ],
#                         [
#                             2746,
#                             1250
#                         ],
#                         [
#                             2797,
#                             1281
#                         ],
#                         [
#                             2827,
#                             1218
#                         ],
#                         [
#                             2870,
#                             1178
#                         ],
#                         [
#                             2881,
#                             1124
#                         ],
#                         [
#                             2915,
#                             1068
#                         ],
#                         [
#                             2895,
#                             966
#                         ],
#                         [
#                             2760,
#                             878
#                         ],
#                         [
#                             2694,
#                             761
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "woe-name": "Cusco",
#                 "hasc": "PE.CS",
#                 "iso": "CUS",
#                 "hc-middle-y": 0.49,
#                 "alt-name": "Cuzco|Qosqo",
#                 "hc-middle-x": 0.52,
#                 "woe-id": "2346475",
#                 "longitude": "-72.2479",
#                 "subregion": null,
#                 "hc-group": "admin1",
#                 "nute": 40808,
#                 "type": "Departamento",
#                 "region": null,
#                 "hc-key": "pe-cs",
#                 "labelrank": "6",
#                 "hc-a2": "CS",
#                 "fips": "PE08",
#                 "type-en": "Department",
#                 "name": "Cusco",
#                 "woe-label": "Cusco, PE, Peru",
#                 "postal-code": "CS",
#                 "country": "Peru",
#                 "latitude": "-13.1633"
#             },
#             "id": "PE.CS",
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             4391,
#                             3182
#                         ],
#                         [
#                             4377,
#                             3115
#                         ],
#                         [
#                             4300,
#                             2974
#                         ],
#                         [
#                             4268,
#                             2835
#                         ],
#                         [
#                             4293,
#                             2763
#                         ],
#                         [
#                             4389,
#                             2706
#                         ],
#                         [
#                             4415,
#                             2622
#                         ],
#                         [
#                             4495,
#                             2579
#                         ],
#                         [
#                             4549,
#                             2443
#                         ],
#                         [
#                             4535,
#                             2378
#                         ],
#                         [
#                             4568,
#                             2313
#                         ],
#                         [
#                             4708,
#                             2257
#                         ],
#                         [
#                             4773,
#                             2257
#                         ],
#                         [
#                             4872,
#                             2211
#                         ],
#                         [
#                             4960,
#                             2185
#                         ],
#                         [
#                             5041,
#                             2131
#                         ],
#                         [
#                             5247,
#                             2094
#                         ],
#                         [
#                             5338,
#                             2107
#                         ],
#                         [
#                             5307,
#                             2142
#                         ],
#                         [
#                             5321,
#                             2162
#                         ],
#                         [
#                             5436,
#                             2150
#                         ],
#                         [
#                             5417,
#                             2063
#                         ],
#                         [
#                             5420,
#                             1998
#                         ],
#                         [
#                             5395,
#                             1952
#                         ],
#                         [
#                             5304,
#                             1847
#                         ],
#                         [
#                             5236,
#                             1702
#                         ],
#                         [
#                             5157,
#                             1681
#                         ],
#                         [
#                             5136,
#                             1571
#                         ],
#                         [
#                             5159,
#                             1521
#                         ],
#                         [
#                             5144,
#                             1443
#                         ],
#                         [
#                             5108,
#                             1336
#                         ],
#                         [
#                             5056,
#                             1317
#                         ],
#                         [
#                             5045,
#                             1236
#                         ],
#                         [
#                             4970,
#                             1177
#                         ],
#                         [
#                             5006,
#                             1133
#                         ],
#                         [
#                             5040,
#                             1125
#                         ],
#                         [
#                             5046,
#                             1026
#                         ],
#                         [
#                             5028,
#                             994
#                         ],
#                         [
#                             5028,
#                             929
#                         ],
#                         [
#                             5047,
#                             863
#                         ],
#                         [
#                             5039,
#                             802
#                         ],
#                         [
#                             5015,
#                             790
#                         ],
#                         [
#                             4930,
#                             866
#                         ],
#                         [
#                             4935,
#                             919
#                         ],
#                         [
#                             4900,
#                             948
#                         ],
#                         [
#                             4868,
#                             925
#                         ],
#                         [
#                             4742,
#                             982
#                         ],
#                         [
#                             4740,
#                             951
#                         ],
#                         [
#                             4651,
#                             929
#                         ],
#                         [
#                             4540,
#                             972
#                         ],
#                         [
#                             4544,
#                             1034
#                         ],
#                         [
#                             4572,
#                             1077
#                         ],
#                         [
#                             4533,
#                             1091
#                         ],
#                         [
#                             4482,
#                             1176
#                         ],
#                         [
#                             4452,
#                             1196
#                         ],
#                         [
#                             4448,
#                             1123
#                         ],
#                         [
#                             4423,
#                             1072
#                         ],
#                         [
#                             4365,
#                             1120
#                         ],
#                         [
#                             4270,
#                             1095
#                         ],
#                         [
#                             4220,
#                             1113
#                         ],
#                         [
#                             4185,
#                             1159
#                         ],
#                         [
#                             4185,
#                             1197
#                         ],
#                         [
#                             4176,
#                             1260
#                         ],
#                         [
#                             4191,
#                             1290
#                         ],
#                         [
#                             4250,
#                             1331
#                         ],
#                         [
#                             4307,
#                             1347
#                         ],
#                         [
#                             4405,
#                             1464
#                         ],
#                         [
#                             4423,
#                             1526
#                         ],
#                         [
#                             4424,
#                             1629
#                         ],
#                         [
#                             4378,
#                             1720
#                         ],
#                         [
#                             4317,
#                             1774
#                         ],
#                         [
#                             4258,
#                             1787
#                         ],
#                         [
#                             4227,
#                             1833
#                         ],
#                         [
#                             4126,
#                             1855
#                         ],
#                         [
#                             4012,
#                             1932
#                         ],
#                         [
#                             3920,
#                             1955
#                         ],
#                         [
#                             3842,
#                             1920
#                         ],
#                         [
#                             3771,
#                             1943
#                         ],
#                         [
#                             3724,
#                             1981
#                         ],
#                         [
#                             3662,
#                             2069
#                         ],
#                         [
#                             3574,
#                             2139
#                         ],
#                         [
#                             3583,
#                             2156
#                         ],
#                         [
#                             3511,
#                             2385
#                         ],
#                         [
#                             3462,
#                             2415
#                         ],
#                         [
#                             3407,
#                             2488
#                         ],
#                         [
#                             3405,
#                             2526
#                         ],
#                         [
#                             3348,
#                             2623
#                         ],
#                         [
#                             3428,
#                             2626
#                         ],
#                         [
#                             3525,
#                             2658
#                         ],
#                         [
#                             3551,
#                             2705
#                         ],
#                         [
#                             3558,
#                             2779
#                         ],
#                         [
#                             3615,
#                             2862
#                         ],
#                         [
#                             3619,
#                             2947
#                         ],
#                         [
#                             3513,
#                             2990
#                         ],
#                         [
#                             3593,
#                             3060
#                         ],
#                         [
#                             3659,
#                             3183
#                         ],
#                         [
#                             3835,
#                             3199
#                         ],
#                         [
#                             3876,
#                             3211
#                         ],
#                         [
#                             3918,
#                             3254
#                         ],
#                         [
#                             3950,
#                             3189
#                         ],
#                         [
#                             4016,
#                             3152
#                         ],
#                         [
#                             4081,
#                             3160
#                         ],
#                         [
#                             4133,
#                             3121
#                         ],
#                         [
#                             4178,
#                             3118
#                         ],
#                         [
#                             4257,
#                             3172
#                         ],
#                         [
#                             4329,
#                             3193
#                         ],
#                         [
#                             4381,
#                             3186
#                         ],
#                         [
#                             4391,
#                             3182
#                         ],
#                         [
#                             4391,
#                             3182
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "woe-name": "Ucayali",
#                 "hasc": "PE.UC",
#                 "iso": "UCA",
#                 "hc-middle-y": 0.79,
#                 "alt-name": null,
#                 "hc-middle-x": 0.59,
#                 "woe-id": "2346492",
#                 "longitude": "-73.24930000000001",
#                 "subregion": null,
#                 "hc-group": "admin1",
#                 "nute": 40425,
#                 "type": "Departamento",
#                 "region": null,
#                 "hc-key": "pe-uc",
#                 "labelrank": "4",
#                 "hc-a2": "UC",
#                 "fips": "PE25",
#                 "type-en": "Department",
#                 "name": "Ucayali",
#                 "woe-label": "Ucayali, PE, Peru",
#                 "postal-code": "UC",
#                 "country": "Peru",
#                 "latitude": "-9.99816"
#             },
#             "id": "PE.UC",
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             4391,
#                             3182
#                         ],
#                         [
#                             4329,
#                             3193
#                         ],
#                         [
#                             4257,
#                             3172
#                         ],
#                         [
#                             4178,
#                             3118
#                         ],
#                         [
#                             4133,
#                             3121
#                         ],
#                         [
#                             4081,
#                             3160
#                         ],
#                         [
#                             4016,
#                             3152
#                         ],
#                         [
#                             3950,
#                             3189
#                         ],
#                         [
#                             3918,
#                             3254
#                         ],
#                         [
#                             3876,
#                             3211
#                         ],
#                         [
#                             3835,
#                             3199
#                         ],
#                         [
#                             3659,
#                             3183
#                         ],
#                         [
#                             3612,
#                             3272
#                         ],
#                         [
#                             3625,
#                             3376
#                         ],
#                         [
#                             3585,
#                             3454
#                         ],
#                         [
#                             3545,
#                             3497
#                         ],
#                         [
#                             3472,
#                             3519
#                         ],
#                         [
#                             3397,
#                             3412
#                         ],
#                         [
#                             3106,
#                             3349
#                         ],
#                         [
#                             3054,
#                             3384
#                         ],
#                         [
#                             3035,
#                             3468
#                         ],
#                         [
#                             3091,
#                             3508
#                         ],
#                         [
#                             3162,
#                             3578
#                         ],
#                         [
#                             3231,
#                             3612
#                         ],
#                         [
#                             3211,
#                             3650
#                         ],
#                         [
#                             3158,
#                             3675
#                         ],
#                         [
#                             3118,
#                             3783
#                         ],
#                         [
#                             3124,
#                             3887
#                         ],
#                         [
#                             3079,
#                             3996
#                         ],
#                         [
#                             3077,
#                             4059
#                         ],
#                         [
#                             3021,
#                             4176
#                         ],
#                         [
#                             2925,
#                             4315
#                         ],
#                         [
#                             2915,
#                             4355
#                         ],
#                         [
#                             2938,
#                             4430
#                         ],
#                         [
#                             2939,
#                             4519
#                         ],
#                         [
#                             2969,
#                             4579
#                         ],
#                         [
#                             2977,
#                             4657
#                         ],
#                         [
#                             3034,
#                             4702
#                         ],
#                         [
#                             3032,
#                             4751
#                         ],
#                         [
#                             3008,
#                             4776
#                         ],
#                         [
#                             2941,
#                             4784
#                         ],
#                         [
#                             2868,
#                             4761
#                         ],
#                         [
#                             2729,
#                             4656
#                         ],
#                         [
#                             2659,
#                             4560
#                         ],
#                         [
#                             2577,
#                             4425
#                         ],
#                         [
#                             2495,
#                             4393
#                         ],
#                         [
#                             2424,
#                             4334
#                         ],
#                         [
#                             2371,
#                             4322
#                         ],
#                         [
#                             2296,
#                             4416
#                         ],
#                         [
#                             2283,
#                             4507
#                         ],
#                         [
#                             2232,
#                             4568
#                         ],
#                         [
#                             2224,
#                             4671
#                         ],
#                         [
#                             2180,
#                             4770
#                         ],
#                         [
#                             2239,
#                             4798
#                         ],
#                         [
#                             2375,
#                             4920
#                         ],
#                         [
#                             2407,
#                             4922
#                         ],
#                         [
#                             2500,
#                             4867
#                         ],
#                         [
#                             2503,
#                             4897
#                         ],
#                         [
#                             2453,
#                             4979
#                         ],
#                         [
#                             2461,
#                             5012
#                         ],
#                         [
#                             2517,
#                             5032
#                         ],
#                         [
#                             2540,
#                             5082
#                         ],
#                         [
#                             2644,
#                             5082
#                         ],
#                         [
#                             2801,
#                             5149
#                         ],
#                         [
#                             2934,
#                             5171
#                         ],
#                         [
#                             2998,
#                             5203
#                         ],
#                         [
#                             3016,
#                             5237
#                         ],
#                         [
#                             3011,
#                             5401
#                         ],
#                         [
#                             2985,
#                             5515
#                         ],
#                         [
#                             2996,
#                             5546
#                         ],
#                         [
#                             3037,
#                             5547
#                         ],
#                         [
#                             3093,
#                             5512
#                         ],
#                         [
#                             3207,
#                             5493
#                         ],
#                         [
#                             3303,
#                             5457
#                         ],
#                         [
#                             3352,
#                             5426
#                         ],
#                         [
#                             3331,
#                             5418
#                         ],
#                         [
#                             3437,
#                             5313
#                         ],
#                         [
#                             3511,
#                             5272
#                         ],
#                         [
#                             3510,
#                             5226
#                         ],
#                         [
#                             3462,
#                             5222
#                         ],
#                         [
#                             3471,
#                             5175
#                         ],
#                         [
#                             3536,
#                             5139
#                         ],
#                         [
#                             3575,
#                             5066
#                         ],
#                         [
#                             3572,
#                             5033
#                         ],
#                         [
#                             3618,
#                             4927
#                         ],
#                         [
#                             3718,
#                             4863
#                         ],
#                         [
#                             3721,
#                             4793
#                         ],
#                         [
#                             3768,
#                             4743
#                         ],
#                         [
#                             3824,
#                             4720
#                         ],
#                         [
#                             3885,
#                             4617
#                         ],
#                         [
#                             3939,
#                             4562
#                         ],
#                         [
#                             3949,
#                             4503
#                         ],
#                         [
#                             3896,
#                             4418
#                         ],
#                         [
#                             3871,
#                             4410
#                         ],
#                         [
#                             3797,
#                             4313
#                         ],
#                         [
#                             4033,
#                             4310
#                         ],
#                         [
#                             4257,
#                             4266
#                         ],
#                         [
#                             4329,
#                             4230
#                         ],
#                         [
#                             4355,
#                             4155
#                         ],
#                         [
#                             4352,
#                             4099
#                         ],
#                         [
#                             4393,
#                             4073
#                         ],
#                         [
#                             4413,
#                             4024
#                         ],
#                         [
#                             4391,
#                             3955
#                         ],
#                         [
#                             4863,
#                             3948
#                         ],
#                         [
#                             4978,
#                             3986
#                         ],
#                         [
#                             4999,
#                             4024
#                         ],
#                         [
#                             5085,
#                             4057
#                         ],
#                         [
#                             5169,
#                             4149
#                         ],
#                         [
#                             5284,
#                             4226
#                         ],
#                         [
#                             5340,
#                             4277
#                         ],
#                         [
#                             5377,
#                             4282
#                         ],
#                         [
#                             5345,
#                             4216
#                         ],
#                         [
#                             5317,
#                             4203
#                         ],
#                         [
#                             5363,
#                             4106
#                         ],
#                         [
#                             5312,
#                             4057
#                         ],
#                         [
#                             5305,
#                             3972
#                         ],
#                         [
#                             5198,
#                             3887
#                         ],
#                         [
#                             5167,
#                             3726
#                         ],
#                         [
#                             5091,
#                             3633
#                         ],
#                         [
#                             4965,
#                             3541
#                         ],
#                         [
#                             4880,
#                             3508
#                         ],
#                         [
#                             4618,
#                             3378
#                         ],
#                         [
#                             4517,
#                             3371
#                         ],
#                         [
#                             4430,
#                             3406
#                         ],
#                         [
#                             4414,
#                             3383
#                         ],
#                         [
#                             4447,
#                             3316
#                         ],
#                         [
#                             4403,
#                             3240
#                         ],
#                         [
#                             4391,
#                             3182
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "woe-name": "Madre de Dios",
#                 "hasc": "PE.MD",
#                 "iso": "MDD",
#                 "hc-middle-y": 0.58,
#                 "alt-name": null,
#                 "hc-middle-x": 0.47,
#                 "woe-id": "2346484",
#                 "longitude": "-70.6831",
#                 "subregion": null,
#                 "hc-group": "admin1",
#                 "nute": 40817,
#                 "type": "Departamento",
#                 "region": null,
#                 "hc-key": "pe-md",
#                 "labelrank": "4",
#                 "hc-a2": "MD",
#                 "fips": "PE17",
#                 "type-en": "Department",
#                 "name": "Madre de Dios",
#                 "woe-label": "Madre de Dios, PE, Peru",
#                 "postal-code": "MD",
#                 "country": "Peru",
#                 "latitude": "-11.8726"
#             },
#             "id": "PE.MD",
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             4403,
#                             3240
#                         ],
#                         [
#                             4447,
#                             3316
#                         ],
#                         [
#                             4414,
#                             3383
#                         ],
#                         [
#                             4430,
#                             3406
#                         ],
#                         [
#                             4517,
#                             3371
#                         ],
#                         [
#                             4618,
#                             3378
#                         ],
#                         [
#                             4880,
#                             3508
#                         ],
#                         [
#                             4965,
#                             3541
#                         ],
#                         [
#                             5091,
#                             3633
#                         ],
#                         [
#                             5167,
#                             3726
#                         ],
#                         [
#                             5198,
#                             3887
#                         ],
#                         [
#                             5305,
#                             3972
#                         ],
#                         [
#                             5293,
#                             3347
#                         ],
#                         [
#                             5356,
#                             3388
#                         ],
#                         [
#                             5412,
#                             3329
#                         ],
#                         [
#                             5498,
#                             3311
#                         ],
#                         [
#                             5552,
#                             3324
#                         ],
#                         [
#                             5695,
#                             3393
#                         ],
#                         [
#                             5782,
#                             3387
#                         ],
#                         [
#                             5833,
#                             3363
#                         ],
#                         [
#                             5917,
#                             3369
#                         ],
#                         [
#                             6417,
#                             2435
#                         ],
#                         [
#                             6352,
#                             2367
#                         ],
#                         [
#                             6380,
#                             2339
#                         ],
#                         [
#                             6361,
#                             2308
#                         ],
#                         [
#                             6313,
#                             2296
#                         ],
#                         [
#                             6238,
#                             2223
#                         ],
#                         [
#                             6239,
#                             2125
#                         ],
#                         [
#                             5867,
#                             1951
#                         ],
#                         [
#                             5842,
#                             1952
#                         ],
#                         [
#                             5456,
#                             2155
#                         ],
#                         [
#                             5436,
#                             2150
#                         ],
#                         [
#                             5321,
#                             2162
#                         ],
#                         [
#                             5307,
#                             2142
#                         ],
#                         [
#                             5338,
#                             2107
#                         ],
#                         [
#                             5247,
#                             2094
#                         ],
#                         [
#                             5041,
#                             2131
#                         ],
#                         [
#                             4960,
#                             2185
#                         ],
#                         [
#                             4872,
#                             2211
#                         ],
#                         [
#                             4773,
#                             2257
#                         ],
#                         [
#                             4708,
#                             2257
#                         ],
#                         [
#                             4568,
#                             2313
#                         ],
#                         [
#                             4535,
#                             2378
#                         ],
#                         [
#                             4549,
#                             2443
#                         ],
#                         [
#                             4495,
#                             2579
#                         ],
#                         [
#                             4415,
#                             2622
#                         ],
#                         [
#                             4389,
#                             2706
#                         ],
#                         [
#                             4293,
#                             2763
#                         ],
#                         [
#                             4268,
#                             2835
#                         ],
#                         [
#                             4300,
#                             2974
#                         ],
#                         [
#                             4377,
#                             3115
#                         ],
#                         [
#                             4391,
#                             3182
#                         ],
#                         [
#                             4391,
#                             3182
#                         ],
#                         [
#                             4403,
#                             3240
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "woe-name": "San Mart\u00edn",
#                 "hasc": "PE.SM",
#                 "iso": "SAM",
#                 "hc-middle-y": 0.6,
#                 "alt-name": "San Mart",
#                 "hc-middle-x": 0.4,
#                 "woe-id": "2346489",
#                 "longitude": "-76.6238",
#                 "subregion": null,
#                 "hc-group": "admin1",
#                 "nute": 40222,
#                 "type": "Departamento",
#                 "region": null,
#                 "hc-key": "pe-sm",
#                 "labelrank": "4",
#                 "hc-a2": "SM",
#                 "fips": "PE22",
#                 "type-en": "Department",
#                 "name": "San Mart\u00edn",
#                 "woe-label": "San Martin, PE, Peru",
#                 "postal-code": "SM",
#                 "country": "Peru",
#                 "latitude": "-7.30853"
#             },
#             "id": "PE.SM",
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             1137,
#                             5743
#                         ],
#                         [
#                             1118,
#                             5763
#                         ],
# ...
#                 "country": "Peru",
#                 "latitude": "-10.3457"
#             },
#             "id": "PE.PA",
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             1727,
#                             3709
#                         ],
#                         [
#                             1781,
#                             3747
#                         ],
#                         [
#                             1819,
#                             3800
#                         ],
#                         [
#                             1865,
#                             3817
#                         ],
#                         [
#                             1983,
#                             3803
#                         ],
#                         [
#                             2031,
#                             3756
#                         ],
#                         [
#                             2144,
#                             3748
#                         ],
#                         [
#                             2196,
#                             3720
#                         ],
#                         [
#                             2299,
#                             3776
#                         ],
#                         [
#                             2265,
#                             3914
#                         ],
#                         [
#                             2282,
#                             3994
#                         ],
#                         [
#                             2321,
#                             4022
#                         ],
#                         [
#                             2389,
#                             4034
#                         ],
#                         [
#                             2460,
#                             4031
#                         ],
#                         [
#                             2560,
#                             4049
#                         ],
#                         [
#                             2672,
#                             4102
#                         ],
#                         [
#                             2760,
#                             4093
#                         ],
#                         [
#                             2889,
#                             4115
#                         ],
#                         [
#                             3021,
#                             4176
#                         ],
#                         [
#                             3077,
#                             4059
#                         ],
#                         [
#                             3079,
#                             3996
#                         ],
#                         [
#                             3124,
#                             3887
#                         ],
#                         [
#                             3118,
#                             3783
#                         ],
#                         [
#                             3158,
#                             3675
#                         ],
#                         [
#                             3211,
#                             3650
#                         ],
#                         [
#                             3231,
#                             3612
#                         ],
#                         [
#                             3162,
#                             3578
#                         ],
#                         [
#                             3091,
#                             3508
#                         ],
#                         [
#                             3035,
#                             3468
#                         ],
#                         [
#                             2932,
#                             3467
#                         ],
#                         [
#                             2876,
#                             3483
#                         ],
#                         [
#                             2801,
#                             3536
#                         ],
#                         [
#                             2734,
#                             3568
#                         ],
#                         [
#                             2676,
#                             3538
#                         ],
#                         [
#                             2545,
#                             3503
#                         ],
#                         [
#                             2488,
#                             3502
#                         ],
#                         [
#                             2308,
#                             3449
#                         ],
#                         [
#                             2169,
#                             3446
#                         ],
#                         [
#                             2144,
#                             3469
#                         ],
#                         [
#                             2092,
#                             3437
#                         ],
#                         [
#                             2005,
#                             3437
#                         ],
#                         [
#                             2002,
#                             3332
#                         ],
#                         [
#                             1880,
#                             3323
#                         ],
#                         [
#                             1832,
#                             3397
#                         ],
#                         [
#                             1831,
#                             3481
#                         ],
#                         [
#                             1792,
#                             3533
#                         ],
#                         [
#                             1786,
#                             3570
#                         ],
#                         [
#                             1727,
#                             3709
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "woe-name": "Piura",
#                 "hasc": "PE.PI",
#                 "iso": "PIU",
#                 "hc-middle-y": 0.46,
#                 "alt-name": null,
#                 "hc-middle-x": 0.55,
#                 "woe-id": "2346487",
#                 "longitude": "-80.2868",
#                 "subregion": null,
#                 "hc-group": "admin1",
#                 "nute": 40120,
#                 "type": "Departamento",
#                 "region": null,
#                 "hc-key": "pe-pi",
#                 "labelrank": "7",
#                 "hc-a2": "PI",
#                 "fips": "PE20",
#                 "type-en": "Department",
#                 "name": "Piura",
#                 "woe-label": "Piura, PE, Peru",
#                 "postal-code": "PI",
#                 "country": "Peru",
#                 "latitude": "-5.09955"
#             },
#             "id": "PE.PI",
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             251,
#                             6936
#                         ],
#                         [
#                             226,
#                             6890
#                         ],
#                         [
#                             164,
#                             6824
#                         ],
#                         [
#                             174,
#                             6740
#                         ],
#                         [
#                             195,
#                             6713
#                         ],
#                         [
#                             198,
#                             6620
#                         ],
#                         [
#                             159,
#                             6621
#                         ],
#                         [
#                             143,
#                             6486
#                         ],
#                         [
#                             182,
#                             6380
#                         ],
#                         [
#                             125,
#                             6331
#                         ],
#                         [
#                             79,
#                             6364
#                         ],
#                         [
#                             9,
#                             6367
#                         ],
#                         [
#                             -7,
#                             6396
#                         ],
#                         [
#                             -56,
#                             6413
#                         ],
#                         [
#                             -53,
#                             6474
#                         ],
#                         [
#                             -91,
#                             6529
#                         ],
#                         [
#                             -169,
#                             6590
#                         ],
#                         [
#                             -171,
#                             6428
#                         ],
#                         [
#                             -197,
#                             6409
#                         ],
#                         [
#                             -380,
#                             6355
#                         ],
#                         [
#                             -466,
#                             6261
#                         ],
#                         [
#                             -488,
#                             6207
#                         ],
#                         [
#                             -571,
#                             6096
#                         ],
#                         [
#                             -666,
#                             6141
#                         ],
#                         [
#                             -704,
#                             6176
#                         ],
#                         [
#                             -852,
#                             6274
#                         ],
#                         [
#                             -882,
#                             6331
#                         ],
#                         [
#                             -882,
#                             6386
#                         ],
#                         [
#                             -838,
#                             6443
#                         ],
#                         [
#                             -757,
#                             6406
#                         ],
#                         [
#                             -713,
#                             6470
#                         ],
#                         [
#                             -709,
#                             6525
#                         ],
#                         [
#                             -754,
#                             6635
#                         ],
#                         [
#                             -838,
#                             6720
#                         ],
#                         [
#                             -874,
#                             6731
#                         ],
#                         [
#                             -914,
#                             6785
#                         ],
#                         [
#                             -898,
#                             6857
#                         ],
#                         [
#                             -846,
#                             6862
#                         ],
#                         [
#                             -835,
#                             6896
#                         ],
#                         [
#                             -931,
#                             7023
#                         ],
#                         [
#                             -999,
#                             7098
#                         ],
#                         [
#                             -980,
#                             7119
#                         ],
#                         [
#                             -995,
#                             7218
#                         ],
#                         [
#                             -966,
#                             7266
#                         ],
#                         [
#                             -975,
#                             7312
#                         ],
#                         [
#                             -950,
#                             7359
#                         ],
#                         [
#                             -837,
#                             7452
#                         ],
#                         [
#                             -758,
#                             7402
#                         ],
#                         [
#                             -693,
#                             7404
#                         ],
#                         [
#                             -616,
#                             7378
#                         ],
#                         [
#                             -511,
#                             7465
#                         ],
#                         [
#                             -485,
#                             7377
#                         ],
#                         [
#                             -411,
#                             7386
#                         ],
#                         [
#                             -496,
#                             7269
#                         ],
#                         [
#                             -448,
#                             7221
#                         ],
#                         [
#                             -348,
#                             7285
#                         ],
#                         [
#                             -328,
#                             7328
#                         ],
#                         [
#                             -289,
#                             7337
#                         ],
#                         [
#                             -195,
#                             7275
#                         ],
#                         [
#                             -149,
#                             7269
#                         ],
#                         [
#                             -106,
#                             7222
#                         ],
#                         [
#                             -3,
#                             7246
#                         ],
#                         [
#                             87,
#                             7192
#                         ],
#                         [
#                             75,
#                             7141
#                         ],
#                         [
#                             122,
#                             7028
#                         ],
#                         [
#                             209,
#                             6939
#                         ],
#                         [
#                             251,
#                             6936
#                         ]
#                     ]
#                 ]
#             }
#         }
#     ],
#     "copyright": "Copyright (c) 2015 Highsoft AS, Based on data from Natural Earth",
#     "hc-transform": {
#         "default": {
#             "scale": 0.000344388016314,
#             "xoffset": 127569.914462,
#             "jsonres": 15.5,
#             "jsonmarginX": -999,
#             "yoffset": 2086634.05039,
#             "jsonmarginY": 9851.0,
#             "crs": "+proj=tmerc +lat_0=-9.5 +lon_0=-76 +k=0.99932994 +x_0=720000 +y_0=1039979.159 +ellps=intl +towgs84=-288,175,-376,0,0,0,0 +units=m +no_defs"
#         }
#     },
#     "type": "FeatureCollection",
#     "version": "1.1.2",
#     "crs": {
#         "type": "name",
#         "properties": {
#             "name": "urn:ogc:def:crs:EPSG:24892"
#         }
#     },
#     "copyrightUrl": "http://www.naturalearthdata.com",
#     "copyrightShort": "Natural Earth"
# }

# %% [markdown]
# ### 2.1 Corrections in TopoJson Data

# %% [markdown]
# Following  the same steps as with GeoJson data, is it possible to correct the error in TopoJson data.

# %%
# Loading Peru TopoJson
topo_file = "./peru_all_topo.json"
topo_handler = open(topo_file, "r")
topo_json = topo_handler.read()
topo_handler.close()
topo_json = json.loads(topo_json)

# %%
# Getting names of properties for each feature in 
topo_properties_list = list(topo_json["objects"]["peru"]["geometries"][0]["properties"].keys())
topo_properties_list.sort()

for property_ in topo_properties_list:
    print("*", property_)
# Out:
# * name

# %%
# Tabulating data of features in geojson
properties_list = ["#", "ID", "Name", "HASC", "ISO", "FIPS", "NUTE"]
str_template = "{0:2s}  {1:10s}{2:20s}{3:10s}{4:10s}{5:10s}{6:10s}"
print(str_template.format(*properties_list))

topo_geometries_list = list(
    (geometry["id"], geometry["properties"]) for geometry in topo_json["objects"]["peru"]["geometries"]
)

geometries_list = topo_geometries_list

str_template = "{0:0>2d}  {1:10s}{2:20s}{3:10s}{4:10s}{5:10s}{6:10s}"

for i, (id_, property_) in enumerate(geometries_list):
    
    property_ = list(
        str(property_[pn.lower()]) if pn.lower() in property_.keys() else "---" for pn in properties_list[2:]
    )
    
    print(
        str_template.format(
            i + 1,
            id_,
            *property_
        )
    )
# Out:
# #   ID        Name                HASC      ISO       FIPS      NUTE
# 01  PE.       Callao              ---       ---       ---       ---
# 02  PE.LB     Lambayeque          ---       ---       ---       ---
# 03  PE.PI     Piura               ---       ---       ---       ---
# 04  PE.TU     Tumbes              ---       ---       ---       ---
# 05  PE.AP     Apurímac            ---       ---       ---       ---
# 06  PE.AR     Arequipa            ---       ---       ---       ---
# 07  PE.CS     Cusco               ---       ---       ---       ---
# 08  PE.MD     Madre de Dios       ---       ---       ---       ---
# 09  PE.CL     Callao              ---       ---       ---       ---
# 10  PE.MQ     Moquegua            ---       ---       ---       ---
# 11  PE.TA     Tacna               ---       ---       ---       ---
# 12  PE.AN     Ancash              ---       ---       ---       ---
# 13  PE.CJ     Cajamarca           ---       ---       ---       ---
# 14  PE.HC     Huánuco             ---       ---       ---       ---
# 15  PE.LL     La Libertad         ---       ---       ---       ---
# 16  PE.PA     Pasco               ---       ---       ---       ---
# 17  PE.SM     San Martín          ---       ---       ---       ---
# 18  PE.UC     Ucayali             ---       ---       ---       ---
# 19  PE.AM     Amazonas            ---       ---       ---       ---
# 20  PE.LO     Loreto              ---       ---       ---       ---
# 21  PE.AY     Ayacucho            ---       ---       ---       ---
# 22  PE.LR     Lima Province       ---       ---       ---       ---
# 23  PE.HV     Huancavelica        ---       ---       ---       ---
# 24  PE.IC     Ica                 ---       ---       ---       ---
# 25  PE.JU     Junín               ---       ---       ---       ---
# 26  PE.LR     Lima                ---       ---       ---       ---

# %% [markdown]
# There is no much information to correct the data, bus since the amount of data is 'small' is posible to check for aditional information in the file. Especifically looking `arcs` property of every geometry and the coordinates corresponding to every `arc`. This is necessary only for ids PE., PE.CL, and PE.LR which apear twice

# %%
topo_metadata = geo_features

for i, geometry in enumerate(topo_json["objects"]["peru"]["geometries"]):      
    if geometry["id"] == "PE.":
        topo_json["objects"]["peru"]["geometries"][i]["id"] = "PE.CL"
        geometry["id"] = "PE.CL"

    elif geometry["id"] == "PE.CL":
        topo_json["objects"]["peru"]["geometries"][i]["id"] = "PE.PU"
        geometry["id"] = "PE.PU"

    elif geometry['properties']["name"] == "Lima Province":
        topo_json["objects"]["peru"]["geometries"][i]["id"] = "PE.LP"
        geometry["id"] = "PE.LP"
    
    topo_json["objects"]["peru"]["geometries"][i]["properties"] = topo_metadata[geometry["id"]]

# %%
# Tabulating data of features in geojson
properties_list = ["#", "ID", "Name", "HASC", "ISO", "FIPS", "NUTE"]
str_template = "{0:2s}  {1:10s}{2:20s}{3:10s}{4:10s}{5:10s}{6:10s}"
print(str_template.format(*properties_list))

topo_geometries = dict(
    (geometry["id"], geometry["properties"]) for geometry in topo_json["objects"]["peru"]["geometries"]
)

geometries_list = list(topo_geometries.items())
geometries_list.sort()

str_template = "{0:0>2d}  {1:10s}{2:20s}{3:10s}{4:10s}{5:10s}{6:10s}"

for i, (id_, property_) in enumerate(geometries_list):
    
    property_ = list(
        str(property_[pn.lower()]) if pn.lower() in property_.keys() else "---" for pn in properties_list[2:]
    )
    
    print(
        str_template.format(
            i + 1,
            id_,
            *property_
        )
    )
# Out:
# #   ID        Name                HASC      ISO       FIPS      NUTE
# 01  PE.AM     Amazonas            PE.AM     AMA       PE01      40201
# 02  PE.AN     Ancash              PE.AN     ANC       PE02      40502
# 03  PE.AP     Apurímac            PE.AP     APU       PE03      40903
# 04  PE.AR     Arequipa            PE.AR     ARE       PE04      41004
# 05  PE.AY     Ayacucho            PE.AY     AYA       PE05      40905
# 06  PE.CJ     Cajamarca           PE.CJ     CAJ       PE06      40106
# 07  PE.CL     Callao              PE.CL     CAL       PE07      40607
# 08  PE.CS     Cusco               PE.CS     CUS       PE08      40808
# 09  PE.HC     Huánuco             PE.HC     HUC       PE10      40410
# 10  PE.HV     Huancavelica        PE.HV     HUV       PE09      40909
# 11  PE.IC     Ica                 PE.IC     ICA       PE11      41011
# 12  PE.JU     Junín               PE.JU     JUN       PE12      40712
# 13  PE.LB     Lambayeque          PE.LB     LAM       PE14      40114
# 14  PE.LL     La Libertad         PE.LL     LAL       PE13      40513
# 15  PE.LO     Loreto              PE.LO     LOR       PE16      40316
# 16  PE.LP     Lima Provincia      PE.LP     LMA       PE26      40615
# 17  PE.LR     Lima                PE.LR     LIM       PE15      40615
# 18  PE.MD     Madre de Dios       PE.MD     MDD       PE17      40817
# 19  PE.MQ     Moquegua            PE.MQ     MOQ       PE18      41118
# 20  PE.PA     Pasco               PE.PA     PAS       PE19      40719
# 21  PE.PI     Piura               PE.PI     PIU       PE20      40120
# 22  PE.PU     Puno                PE.PU     PUN       PE21      41121
# 23  PE.SM     San Martín          PE.SM     SAM       PE22      40222
# 24  PE.TA     Tacna               PE.TA     TAC       PE23      41123
# 25  PE.TU     Tumbes              PE.TU     TUM       PE24      40124
# 26  PE.UC     Ucayali             PE.UC     UCA       PE25      40425

# %%
topo_json = json.dumps(topo_json, indent=4)
topo_json = topo_json.strip('"')
topo_json = topo_json.replace('\\n', '\n')
topo_json = topo_json.replace('\\"', '"')
topo_json = topo_json + '\n'
print(topo_json)

topo_file = "./peru_topo.json"
topo_handler = open(topo_file, "w")
topo_handler.write(topo_json.encode('UTF-8').decode('UTF-8'))
topo_handler.close()
# Out:
# {
#     "transform": {
#         "scale": [
#             0.001265457050305029,
#             0.0018310484543392366
#         ],
#         "translate": [
#             -81.33755752899992,
#             -18.337746206937936
#         ]
#     },
#     "type": "Topology",
#     "arcs": [
#         [
#             [
#                 3281,
#                 3402
#             ],
#             [
#                 3,
#                 -4
#             ],
#             [
#                 -8,
#                 2
#             ],
#             [
#                 -10,
#                 -1
#             ],
#             [
#                 -10,
#                 5
#             ],
#             [
#                 -15,
#                 6
#             ],
#             [
#                 -9,
#                 9
#             ],
#             [
#                 -5,
#                 8
#             ],
#             [
#                 8,
#                 2
#             ],
#             [
#                 9,
#                 -3
#             ],
#             [
#                 30,
#                 -19
#             ],
#             [
#                 7,
#                 -5
#             ]
#         ],
#         [
#             [
#                 3337,
#                 3417
#             ],
#             [
#                 -14,
#                 3
#             ],
#             [
#                 -34,
#                 2
#             ],
#             [
#                 7,
#                 10
#             ],
#             [
#                 9,
#                 8
#             ],
#             [
#                 8,
#                 9
#             ],
#             [
#                 3,
#                 13
#             ]
#         ],
#         [
#             [
#                 3316,
#                 3462
#             ],
#             [
#                 1,
#                 0
#             ],
#             [
#                 22,
#                 -11
#             ],
#             [
#                 4,
#                 -13
#             ],
#             [
#                 -2,
#                 -14
#             ],
#             [
#                 -4,
#                 -7
#             ]
#         ],
#         [
#             [
#                 1491,
#                 6744
#             ],
#             [
#                 10,
#                 -7
#             ],
#             [
#                 9,
#                 1
#             ],
#             [
#                 8,
#                 3
#             ],
#             [
#                 8,
#                 3
#             ],
#             [
#                 13,
#                 2
#             ],
#             [
#                 8,
#                 -1
#             ],
#             [
#                 5,
#                 -3
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 0,
#                 -2
#             ],
#             [
#                 4,
#                 -5
#             ],
#             [
#                 17,
#                 9
#             ],
#             [
#                 9,
#                 6
#             ],
#             [
#                 10,
#                 3
#             ],
#             [
#                 8,
#                 0
#             ],
#             [
#                 7,
#                 -3
#             ],
#             [
#                 5,
#                 -3
#             ],
#             [
#                 5,
#                 -3
#             ],
#             [
#                 15,
#                 -5
#             ],
#             [
#                 19,
#                 -4
#             ],
#             [
#                 11,
#                 -3
#             ],
#             [
#                 8,
#                 -4
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 0,
#                 -6
#             ],
#             [
#                 -2,
#                 -6
#             ],
#             [
#                 -3,
#                 -5
#             ],
#             [
#                 -5,
#                 -5
#             ],
#             [
#                 -46,
#                 -29
#             ],
#             [
#                 -5,
#                 -5
#             ],
#             [
#                 -2,
#                 -5
#             ],
#             [
#                 0,
#                 -7
#             ],
#             [
#                 3,
#                 -6
#             ],
#             [
#                 8,
#                 -5
#             ],
#             [
#                 11,
#                 -2
#             ],
#             [
#                 11,
#                 -4
#             ],
#             [
#                 4,
#                 -5
#             ],
#             [
#                 -1,
#                 -7
#             ],
#             [
#                 -7,
#                 -15
#             ],
#             [
#                 -27,
#                 -20
#             ],
#             [
#                 -64,
#                 -8
#             ],
#             [
#                 -18,
#                 -5
#             ],
#             [
#                 -13,
#                 -4
#             ],
#             [
#                 -9,
#                 -5
#             ],
#             [
#                 -12,
#                 -8
#             ],
#             [
#                 -8,
#                 -7
#             ],
#             [
#                 -7,
#                 -8
#             ],
#             [
#                 -3,
#                 -7
#             ],
#             [
#                 0,
#                 -6
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 12,
#                 -13
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 1,
#                 -6
#             ],
#             [
#                 -2,
#                 -6
#             ],
#             [
#                 -8,
#                 -14
#             ],
#             [
#                 5,
#                 -25
#             ],
#             [
#                 4,
#                 -4
#             ],
#             [
#                 7,
#                 -4
#             ],
#             [
#                 8,
#                 0
#             ],
#             [
#                 8,
#                 1
#             ],
#             [
#                 9,
#                 -1
#             ],
#             [
#                 11,
#                 -4
#             ],
#             [
#                 7,
#                 -6
#             ],
#             [
#                 5,
#                 -6
#             ],
#             [
#                 13,
#                 -28
#             ],
#             [
#                 15,
#                 -22
#             ],
#             [
#                 11,
#                 -8
#             ],
#             [
#                 11,
#                 -5
#             ],
#             [
#                 18,
#                 1
#             ],
#             [
#                 19,
#                 0
#             ],
#             [
#                 23,
#                 -9
#             ],
#             [
#                 39,
#                 -5
#             ],
#             [
#                 7,
#                 -3
#             ],
#             [
#                 7,
#                 -6
#             ],
#             [
#                 2,
#                 -6
#             ],
#             [
#                 0,
#                 -6
#             ],
#             [
#                 -1,
#                 -7
#             ],
#             [
#                 -2,
#                 -6
#             ],
#             [
#                 -4,
#                 -4
#             ],
#             [
#                 -7,
#                 -4
#             ],
#             [
#                 -14,
#                 -4
#             ],
#             [
#                 -10,
#                 -5
#             ],
#             [
#                 -26,
#                 -26
#             ],
#             [
#                 -17,
#                 -9
#             ],
#             [
#                 -20,
#                 -5
#             ],
#             [
#                 -14,
#                 -5
#             ],
#             [
#                 -6,
#                 -4
#             ],
#             [
#                 -4,
#                 -6
#             ],
#             [
#                 2,
#                 -44
#             ],
#             [
#                 -2,
#                 -8
#             ],
#             [
#                 -2,
#                 -4
#             ],
#             [
#                 -5,
#                 -4
#             ],
#             [
#                 -5,
#                 -1
#             ],
#             [
#                 -10,
#                 -1
#             ]
#         ],
#         [
#             [
#                 1572,
#                 6186
#             ],
#             [
#                 -21,
#                 13
#             ],
#             [
#                 -74,
#                 14
#             ],
#             [
#                 -12,
#                 0
#             ],
#             [
#                 -7,
#                 -2
#             ],
#             [
#                 -5,
#                 -2
#             ],
#             [
#                 -133,
#                 -89
#             ],
#             [
#                 -20,
#                 -16
#             ]
#         ],
#         [
#             [
#                 1300,
#                 6104
#             ],
#             [
#                 1,
#                 2
#             ],
#             [
#                 2,
#                 14
#             ],
#             [
#                 -15,
#                 14
#             ],
#             [
#                 -84,
#                 57
#             ],
#             [
#                 -41,
#                 28
#             ],
#             [
#                 -9,
#                 12
#             ],
#             [
#                 -43,
#                 25
#             ],
#             [
#                 -11,
#                 17
#             ],
#             [
#                 -3,
#                 17
#             ],
#             [
#                 -12,
#                 18
#             ],
#             [
#                 -19,
#                 16
#             ],
#             [
#                 -13,
#                 9
#             ],
#             [
#                 -90,
#                 50
#             ],
#             [
#                 -40,
#                 17
#             ],
#             [
#                 -102,
#                 41
#             ],
#             [
#                 -128,
#                 44
#             ],
#             [
#                 -134,
#                 47
#             ]
#         ],
#         [
#             [
#                 559,
#                 6532
#             ],
#             [
#                 17,
#                 10
#             ],
#             [
#                 27,
#                 22
#             ],
#             [
#                 67,
#                 70
#             ],
#             [
#                 5,
#                 6
#             ],
#             [
#                 9,
#                 22
#             ],
#             [
#                 5,
#                 8
#             ],
#             [
#                 13,
#                 14
#             ],
#             [
#                 95,
#                 77
#             ],
#             [
#                 10,
#                 5
#             ],
#             [
#                 10,
#                 3
#             ],
#             [
#                 245,
#                 49
#             ],
#             [
#                 28,
#                 13
#             ],
#             [
#                 6,
#                 4
#             ],
#             [
#                 5,
#                 9
#             ],
#             [
#                 4,
#                 16
#             ],
#             [
#                 -3,
#                 57
#             ],
#             [
#                 -13,
#                 54
#             ],
#             [
#                 3,
#                 12
#             ],
#             [
#                 5,
#                 2
#             ],
#             [
#                 4,
#                 0
#             ],
#             [
#                 20,
#                 -10
#             ],
#             [
#                 35,
#                 -22
#             ],
#             [
#                 48,
#                 -25
#             ],
#             [
#                 8,
#                 -6
#             ],
#             [
#                 12,
#                 -12
#             ],
#             [
#                 4,
#                 -7
#             ],
#             [
#                 5,
#                 -6
#             ],
#             [
#                 4,
#                 -5
#             ],
#             [
#                 11,
#                 -9
#             ],
#             [
#                 7,
#                 -6
#             ],
#             [
#                 2,
#                 -6
#             ],
#             [
#                 -2,
#                 -5
#             ],
#             [
#                 -4,
#                 -5
#             ],
#             [
#                 -4,
#                 -4
#             ],
#             [
#                 -7,
#                 -10
#             ],
#             [
#                 -2,
#                 -5
#             ],
#             [
#                 -1,
#                 -4
#             ],
#             [
#                 0,
#                 -3
#             ],
#             [
#                 2,
#                 -5
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 7,
#                 -4
#             ],
#             [
#                 13,
#                 -2
#             ],
#             [
#                 22,
#                 -1
#             ],
#             [
#                 10,
#                 -3
#             ],
#             [
#                 10,
#                 -3
#             ],
#             [
#                 11,
#                 -7
#             ],
#             [
#                 7,
#                 -6
#             ],
#             [
#                 5,
#                 -5
#             ],
#             [
#                 10,
#                 -16
#             ],
#             [
#                 6,
#                 -4
#             ],
#             [
#                 8,
#                 -3
#             ],
#             [
#                 16,
#                 -1
#             ],
#             [
#                 8,
#                 -1
#             ],
#             [
#                 17,
#                 2
#             ],
#             [
#                 17,
#                 4
#             ],
#             [
#                 10,
#                 0
#             ],
#             [
#                 10,
#                 0
#             ],
#             [
#                 32,
#                 -7
#             ],
#             [
#                 9,
#                 -3
#             ],
#             [
#                 6,
#                 -4
#             ],
#             [
#                 15,
#                 -17
#             ]
#         ],
#         [
#             [
#                 394,
#                 6479
#             ],
#             [
#                 -9,
#                 -1
#             ],
#             [
#                 -11,
#                 0
#             ],
#             [
#                 -2,
#                 5
#             ],
#             [
#                 3,
#                 6
#             ],
#             [
#                 -3,
#                 8
#             ],
#             [
#                 -7,
#                 5
#             ],
#             [
#                 6,
#                 4
#             ],
#             [
#                 3,
#                 8
#             ],
#             [
#                 9,
#                 19
#             ],
#             [
#                 8,
#                 -3
#             ],
#             [
#                 -5,
#                 -4
#             ],
#             [
#                 -5,
#                 -9
#             ],
#             [
#                 4,
#                 -8
#             ],
#             [
#                 7,
#                 -5
#             ],
#             [
#                 0,
#                 -7
#             ],
#             [
#                 -1,
#                 -9
#             ],
#             [
#                 3,
#                 -9
#             ]
#         ],
#         [
#             [
#                 1663,
#                 7303
#             ],
#             [
#                 -21,
#                 -14
#             ],
#             [
#                 -5,
#                 -7
#             ],
#             [
#                 -4,
#                 -13
#             ],
#             [
#                 -4,
#                 -8
#             ],
#             [
#                 -7,
#                 -2
#             ],
#             [
#                 -10,
#                 -2
#             ],
#             [
#                 -9,
#                 -5
#             ],
#             [
#                 -14,
#                 -21
#             ],
#             [
#                 -8,
#                 -8
#             ],
#             [
#                 -14,
#                 -8
#             ],
#             [
#                 -21,
#                 -16
#             ],
#             [
#                 -6,
#                 -9
#             ],
#             [
#                 -1,
#                 -7
#             ],
#             [
#                 19,
#                 -32
#             ],
#             [
#                 2,
#                 -7
#             ],
#             [
#                 0,
#                 -9
#             ],
#             [
#                 -1,
#                 -14
#             ],
#             [
#                 2,
#                 -7
#             ],
#             [
#                 6,
#                 -5
#             ],
#             [
#                 8,
#                 -2
#             ],
#             [
#                 7,
#                 -4
#             ],
#             [
#                 5,
#                 -6
#             ],
#             [
#                 7,
#                 -75
#             ],
#             [
#                 -4,
#                 -11
#             ],
#             [
#                 -11,
#                 0
#             ],
#             [
#                 -8,
#                 2
#             ],
#             [
#                 -8,
#                 1
#             ],
#             [
#                 -14,
#                 1
#             ],
#             [
#                 -8,
#                 -2
#             ],
#             [
#                 -3,
#                 -1
#             ],
#             [
#                 -12,
#                 -19
#             ],
#             [
#                 -2,
#                 -4
#             ],
#             [
#                 0,
#                 -2
#             ],
#             [
#                 0,
#                 -3
#             ],
#             [
#                 2,
#                 -6
#             ],
#             [
#                 5,
#                 -8
#             ],
#             [
#                 1,
#                 -3
#             ],
#             [
#                 0,
#                 -3
#             ],
#             [
#                 1,
#                 -11
#             ],
#             [
#                 -6,
#                 -30
#             ],
#             [
#                 -12,
#                 -36
#             ],
#             [
#                 1,
#                 -9
#             ],
#             [
#                 2,
#                 -6
#             ],
#             [
#                 11,
#                 -16
#             ],
#             [
#                 2,
#                 -6
#             ],
#             [
#                 0,
#                 -13
#             ],
#             [
#                 0,
#                 -1
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 1,
#                 -1
#             ],
#             [
#                 1,
#                 -1
#             ],
#             [
#                 9,
#                 -6
#             ],
#             [
#                 11,
#                 -7
#             ],
#             [
#                 7,
#                 -22
#             ],
#             [
#                 -9,
#                 -8
#             ],
#             [
#                 -7,
#                 -3
#             ],
#             [
#                 -8,
#                 -3
#             ],
#             [
#                 -9,
#                 -5
#             ],
#             [
#                 -28,
#                 -20
#             ],
#             [
#                 -14,
#                 -6
#             ]
#         ],
#         [
#             [
#                 559,
#                 6532
#             ],
#             [
#                 -77,
#                 26
#             ],
#             [
#                 -50,
#                 16
#             ],
#             [
#                 -49,
#                 33
#             ],
#             [
#                 -58,
#                 28
#             ],
#             [
#                 -69,
#                 27
#             ],
#             [
#                 -69,
#                 37
#             ],
#             [
#                 -24,
#                 20
#             ],
#             [
#                 -16,
#                 32
#             ],
#             [
#                 2,
#                 22
#             ],
#             [
#                 0,
#                 24
#             ],
#             [
#                 -1,
#                 5
#             ],
#             [
#                 16,
#                 9
#             ],
#             [
#                 5,
#                 11
#             ],
#             [
#                 4,
#                 4
#             ],
#             [
#                 18,
#                 0
#             ],
#             [
#                 8,
#                 13
#             ],
#             [
#                 1,
#                 8
#             ],
#             [
#                 7,
#                 8
#             ],
#             [
#                 14,
#                 -1
#             ],
#             [
#                 16,
#                 -17
#             ],
#             [
#                 22,
#                 -7
#             ],
#             [
#                 30,
#                 -8
#             ],
#             [
#                 25,
#                 -2
#             ],
#             [
#                 29,
#                 19
#             ],
#             [
#                 31,
#                 39
#             ],
#             [
#                 6,
#                 51
#             ],
#             [
#                 -19,
#                 42
#             ],
#             [
#                 -40,
#                 60
#             ],
#             [
#                 -24,
#                 18
#             ],
#             [
#                 -74,
#                 50
#             ],
#             [
#                 -13,
#                 11
#             ],
#             [
#                 -18,
#                 3
#             ],
#             [
#                 -10,
#                 -2
#             ],
#             [
#                 -19,
#                 9
#             ],
#             [
#                 -17,
#                 18
#             ],
#             [
#                 -20,
#                 16
#             ],
#             [
#                 -16,
#                 17
#             ],
#             [
#                 4,
#                 5
#             ],
#             [
#                 5,
#                 4
#             ],
#             [
#                 10,
#                 3
#             ],
#             [
#                 7,
#                 11
#             ],
#             [
#                 -3,
#                 7
#             ],
#             [
#                 -7,
#                 5
#             ],
#             [
#                 1,
#                 7
#             ],
#             [
#                 11,
#                 2
#             ],
#             [
#                 -3,
#                 10
#             ],
#             [
#                 -4,
#                 12
#             ],
#             [
#                 7,
#                 8
#             ],
#             [
#                 13,
#                 -2
#             ],
#             [
#                 14,
#                 6
#             ],
#             [
#                 13,
#                 -9
#             ],
#             [
#                 23,
#                 1
#             ],
#             [
#                 12,
#                 12
#             ],
#             [
#                 4,
#                 19
#             ],
#             [
#                 -17,
#                 26
#             ],
#             [
#                 -27,
#                 19
#             ],
#             [
#                 -24,
#                 13
#             ],
#             [
#                 -19,
#                 19
#             ],
#             [
#                 -13,
#                 16
#             ],
#             [
#                 -27,
#                 25
#             ],
#             [
#                 -63,
#                 47
#             ],
#             [
#                 -27,
#                 23
#             ],
#             [
#                 4,
#                 7
#             ],
#             [
#                 10,
#                 4
#             ],
#             [
#                 12,
#                 8
#             ],
#             [
#                 -3,
#                 11
#             ],
#             [
#                 -6,
#                 12
#             ],
#             [
#                 6,
#                 28
#             ],
#             [
#                 1,
#                 9
#             ],
#             [
#                 -5,
#                 9
#             ],
#             [
#                 -7,
#                 12
#             ],
#             [
#                 -5,
#                 10
#             ],
#             [
#                 3,
#                 8
#             ],
#             [
#                 8,
#                 5
#             ],
#             [
#                 6,
#                 3
#             ],
#             [
#                 5,
#                 3
#             ],
#             [
#                 6,
#                 6
#             ],
#             [
#                 11,
#                 19
#             ],
#             [
#                 0,
#                 12
#             ],
#             [
#                 -11,
#                 31
#             ],
#             [
#                 3,
#                 11
#             ],
#             [
#                 9,
#                 13
#             ],
#             [
#                 11,
#                 12
#             ],
#             [
#                 9,
#                 7
#             ],
#             [
#                 69,
#                 32
#             ],
#             [
#                 18,
#                 13
#             ],
#             [
#                 14,
#                 18
#             ],
#             [
#                 12,
#                 9
#             ],
#             [
#                 15,
#                 3
#             ],
#             [
#                 14,
#                 3
#             ],
#             [
#                 8,
#                 6
#             ],
#             [
#                 1,
#                 1
#             ]
#         ],
#         [
#             [
#                 218,
#                 7785
#             ],
#             [
#                 1,
#                 -1
#             ],
#             [
#                 51,
#                 -33
#             ],
#             [
#                 15,
#                 -6
#             ],
#             [
#                 39,
#                 -7
#             ],
#             [
#                 63,
#                 3
#             ],
#             [
#                 23,
#                 -1
#             ],
#             [
#                 26,
#                 -5
#             ],
#             [
#                 76,
#                 -20
#             ],
#             [
#                 10,
#                 0
#             ],
#             [
#                 4,
#                 0
#             ],
#             [
#                 5,
#                 2
#             ],
#             [
#                 6,
#                 4
#             ],
#             [
#                 16,
#                 14
#             ],
#             [
#                 99,
#                 60
#             ]
#         ],
#         [
#             [
#                 652,
#                 7795
#             ],
#             [
#                 -1,
#                 -10
#             ],
#             [
#                 4,
#                 -7
#             ],
#             [
#                 13,
#                 -12
#             ],
#             [
#                 4,
#                 -7
#             ],
#             [
#                 0,
#                 -5
#             ],
#             [
#                 -3,
#                 -11
#             ],
#             [
#                 0,
#                 -5
#             ],
#             [
#                 17,
#                 -24
#             ],
#             [
#                 27,
#                 -2
#             ],
#             [
#                 35,
#                 7
#             ],
#             [
#                 36,
#                 3
#             ],
#             [
#                 -9,
#                 -12
#             ],
#             [
#                 -104,
#                 -96
#             ],
#             [
#                 -3,
#                 -9
#             ],
#             [
#                 7,
#                 -12
#             ],
#             [
#                 11,
#                 -6
#             ],
#             [
#                 35,
#                 -14
#             ],
#             [
#                 13,
#                 -3
#             ],
#             [
#                 14,
#                 0
#             ],
#             [
#                 6,
#                 0
#             ],
#             [
#                 8,
#                 5
#             ],
#             [
#                 32,
#                 12
#             ],
#             [
#                 61,
#                 32
#             ],
#             [
#                 13,
#                 9
#             ],
#             [
#                 5,
#                 9
#             ],
#             [
#                 9,
#                 19
#             ],
#             [
#                 6,
#                 8
#             ],
#             [
#                 7,
#                 4
#             ],
#             [
#                 8,
#                 2
#             ],
#             [
#                 9,
#                 2
#             ],
#             [
#                 32,
#                 3
#             ],
#             [
#                 2,
#                 1
#             ],
#             [
#                 5,
#                 -6
#             ],
#             [
#                 13,
#                 -3
#             ],
#             [
#                 16,
#                 -2
#             ],
#             [
#                 14,
#                 -3
#             ],
#             [
#                 14,
#                 -9
#             ],
#             [
#                 26,
#                 -19
#             ],
#             [
#                 16,
#                 -8
#             ],
#             [
#                 21,
#                 -8
#             ],
#             [
#                 21,
#                 -2
#             ],
#             [
#                 20,
#                 0
#             ],
#             [
#                 21,
#                 -3
#             ],
#             [
#                 20,
#                 -13
#             ],
#             [
#                 16,
#                 -17
#             ],
#             [
#                 20,
#                 -14
#             ],
#             [
#                 29,
#                 -3
#             ],
#             [
#                 53,
#                 11
#             ],
#             [
#                 28,
#                 11
#             ],
#             [
#                 28,
#                 3
#             ],
#             [
#                 22,
#                 -8
#             ],
#             [
#                 40,
#                 -27
#             ],
#             [
#                 6,
#                 -2
#             ],
#             [
#                 11,
#                 -6
#             ],
#             [
#                 5,
#                 -2
#             ],
#             [
#                 19,
#                 1
#             ],
#             [
#                 16,
#                 -7
#             ],
#             [
#                 5,
#                 -5
#             ],
#             [
#                 -2,
#                 -8
#             ],
#             [
#                 -18,
#                 -22
#             ],
#             [
#                 -1,
#                 -12
#             ],
#             [
#                 23,
#                 -23
#             ],
#             [
#                 9,
#                 -33
#             ],
#             [
#                 21,
#                 -27
#             ],
#             [
#                 2,
#                 -11
#             ],
#             [
#                 6,
#                 -11
#             ],
#             [
#                 14,
#                 -8
#             ],
#             [
#                 16,
#                 -6
#             ],
#             [
#                 14,
#                 -7
#             ],
#             [
#                 4,
#                 -4
#             ],
#             [
#                 5,
#                 -11
#             ],
#             [
#                 4,
#                 -5
#             ],
#             [
#                 7,
#                 -3
#             ],
#             [
#                 16,
#                 -4
#             ],
#             [
#                 7,
#                 -3
#             ],
#             [
#                 10,
#                 -11
#             ],
#             [
#                 9,
#                 -11
#             ],
#             [
#                 11,
#                 -10
#             ],
#             [
#                 18,
#                 -3
#             ],
#             [
#                 37,
#                 1
#             ]
#         ],
#         [
#             [
#                 218,
#                 7785
#             ],
#             [
#                 12,
#                 16
#             ],
#             [
#                 42,
#                 45
#             ],
#             [
#                 25,
#                 17
#             ],
#             [
#                 30,
#                 17
#             ],
#             [
#                 32,
#                 12
#             ],
#             [
#                 12,
#                 8
#             ],
#             [
#                 5,
#                 11
#             ],
#             [
#                 2,
#                 13
#             ],
#             [
#                 5,
#                 11
#             ],
#             [
#                 15,
#                 19
#             ],
#             [
#                 21,
#                 19
#             ],
#             [
#                 28,
#                 16
#             ],
#             [
#                 125,
#                 51
#             ],
#             [
#                 23,
#                 15
#             ],
#             [
#                 33,
#                 34
#             ],
#             [
#                 5,
#                 12
#             ],
#             [
#                 7,
#                 1
#             ],
#             [
#                 8,
#                 1
#             ],
#             [
#                 7,
#                 3
#             ],
#             [
#                 12,
#                 3
#             ],
#             [
#                 55,
#                 -1
#             ],
#             [
#                 15,
#                 2
#             ],
#             [
#                 16,
#                 5
#             ],
#             [
#                 13,
#                 7
#             ],
#             [
#                 5,
#                 10
#             ],
#             [
#                 3,
#                 6
#             ],
#             [
#                 10,
#                 12
#             ],
#             [
#                 3,
#                 6
#             ],
#             [
#                 1,
#                 6
#             ],
#             [
#                 5,
#                 -2
#             ],
#             [
#                 13,
#                 -5
#             ],
#             [
#                 30,
#                 -5
#             ],
#             [
#                 11,
#                 -6
#             ],
#             [
#                 -2,
#                 -10
#             ],
#             [
#                 -4,
#                 -11
#             ],
#             [
#                 1,
#                 -12
#             ],
#             [
#                 5,
#                 -3
#             ],
#             [
#                 13,
#                 -3
#             ],
#             [
#                 5,
#                 -4
#             ],
#             [
#                 2,
#                 -5
#             ],
#             [
#                 0,
#                 -6
#             ],
#             [
#                 -1,
#                 -10
#             ],
#             [
#                 -6,
#                 -15
#             ],
#             [
#                 -1,
#                 -4
#             ],
#             [
#                 6,
#                 -4
#             ],
#             [
#                 7,
#                 -2
#             ],
#             [
#                 7,
#                 -2
#             ],
#             [
#                 2,
#                 -5
#             ],
#             [
#                 0,
#                 -6
#             ],
#             [
#                 5,
#                 -10
#             ],
#             [
#                 1,
#                 -6
#             ],
#             [
#                 -1,
#                 -6
#             ],
#             [
#                 -5,
#                 -10
#             ],
#             [
#                 -2,
#                 -5
#             ],
#             [
#                 0,
#                 -6
#             ],
#             [
#                 1,
#                 -4
#             ],
#             [
#                 5,
#                 -10
#             ],
#             [
#                 1,
#                 -6
#             ],
#             [
#                 -3,
#                 -4
#             ],
#             [
#                 -3,
#                 -4
#             ],
#             [
#                 -2,
#                 -4
#             ],
#             [
#                 4,
#                 -11
#             ],
#             [
#                 16,
#                 -17
#             ],
#             [
#                 7,
#                 -11
#             ],
#             [
#                 1,
#                 -5
#             ],
#             [
#                 0,
#                 -10
#             ],
#             [
#                 2,
#                 -5
#             ],
#             [
#                 7,
#                 -5
#             ],
#             [
#                 7,
#                 -4
#             ],
#             [
#                 5,
#                 -3
#             ],
#             [
#                 -1,
#                 -6
#             ],
#             [
#                 -12,
#                 -9
#             ],
#             [
#                 -62,
#                 -20
#             ],
#             [
#                 -11,
#                 -9
#             ],
#             [
#                 -11,
#                 -13
#             ],
#             [
#                 -14,
#                 -11
#             ],
#             [
#                 -16,
#                 -6
#             ],
#             [
#                 -15,
#                 2
#             ],
#             [
#                 -33,
#                 12
#             ],
#             [
#                 -17,
#                 4
#             ],
#             [
#                 -16,
#                 1
#             ],
#             [
#                 -16,
#                 -1
#             ],
#             [
#                 -14,
#                 -3
#             ],
#             [
#                 -12,
#                 -6
#             ],
#             [
#                 -9,
#                 -9
#             ],
#             [
#                 -9,
#                 -13
#             ],
#             [
#                 -7,
#                 -14
#             ]
#         ],
#         [
#             [
#                 6414,
#                 2685
#             ],
#             [
#                 28,
#                 -6
#             ],
#             [
#                 7,
#                 -3
#             ],
#             [
#                 5,
#                 -2
#             ],
#             [
#                 6,
#                 2
#             ],
#             [
#                 6,
#                 3
#             ],
#             [
#                 5,
#                 2
#             ],
#             [
#                 15,
#                 -4
#             ],
#             [
#                 12,
#                 -8
#             ],
#             [
#                 14,
#                 -4
#             ],
#             [
#                 18,
#                 7
#             ],
#             [
#                 14,
#                 9
#             ],
#             [
#                 6,
#                 2
#             ],
#             [
#                 10,
#                 2
#             ],
#             [
#                 3,
#                 -1
#             ],
#             [
#                 8,
#                 -3
#             ],
#             [
#                 5,
#                 0
#             ],
#             [
#                 4,
#                 1
#             ],
#             [
#                 2,
#                 0
#             ],
#             [
#                 24,
#                 13
#             ],
#             [
#                 11,
#                 3
#             ],
#             [
#                 26,
#                 2
#             ],
#             [
#                 21,
#                 0
#             ],
#             [
#                 5,
#                 -2
#             ],
#             [
#                 1,
#                 -5
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 5,
#                 -5
#             ],
#             [
#                 4,
#                 -2
#             ],
#             [
#                 32,
#                 0
#             ],
#             [
#                 30,
#                 -3
#             ],
#             [
#                 25,
#                 -9
#             ],
#             [
#                 53,
#                 -28
#             ],
#             [
#                 57,
#                 -22
#             ],
#             [
#                 9,
#                 -1
#             ],
#             [
#                 6,
#                 -2
#             ],
#             [
#                 7,
#                 -8
#             ],
#             [
#                 8,
#                 -1
#             ],
#             [
#                 32,
#                 -2
#             ],
#             [
#                 31,
#                 -6
#             ],
#             [
#                 4,
#                 -2
#             ],
#             [
#                 4,
#                 -2
#             ],
#             [
#                 5,
#                 -2
#             ],
#             [
#                 11,
#                 -1
#             ],
#             [
#                 32,
#                 0
#             ],
#             [
#                 11,
#                 -3
#             ],
#             [
#                 9,
#                 -7
#             ],
#             [
#                 16,
#                 -17
#             ],
#             [
#                 -6,
#                 -4
#             ],
#             [
#                 10,
#                 -7
#             ],
#             [
#                 14,
#                 -7
#             ],
#             [
#                 30,
#                 -12
#             ],
#             [
#                 12,
#                 -2
#             ],
#             [
#                 40,
#                 2
#             ],
#             [
#                 4,
#                 -3
#             ],
#             [
#                 25,
#                 -13
#             ],
#             [
#                 6,
#                 -1
#             ],
#             [
#                 7,
#                 -5
#             ],
#             [
#                 42,
#                 -26
#             ],
#             [
#                 12,
#                 -12
#             ],
#             [
#                 8,
#                 -13
#             ],
#             [
#                 18,
#                 -22
#             ],
#             [
#                 3,
#                 -6
#             ],
#             [
#                 14,
#                 -15
#             ],
#             [
#                 11,
#                 -16
#             ],
#             [
#                 0,
#                 -95
#             ],
#             [
#                 -24,
#                 -58
#             ],
#             [
#                 -8,
#                 -10
#             ],
#             [
#                 -5,
#                 -4
#             ],
#             [
#                 -5,
#                 -4
#             ],
#             [
#                 -27,
#                 -12
#             ],
#             [
#                 -6,
#                 -4
#             ],
#             [
#                 -6,
#                 -4
#             ],
#             [
#                 -19,
#                 -17
#             ],
#             [
#                 -19,
#                 -13
#             ],
#             [
#                 -7,
#                 -7
#             ],
#             [
#                 -22,
#                 -29
#             ],
#             [
#                 -7,
#                 -5
#             ],
#             [
#                 -28,
#                 -5
#             ],
#             [
#                 -11,
#                 -4
#             ],
#             [
#                 -13,
#                 -2
#             ],
#             [
#                 -17,
#                 -1
#             ],
#             [
#                 -9,
#                 -4
#             ],
#             [
#                 -5,
#                 -4
#             ],
#             [
#                 -5,
#                 -6
#             ],
#             [
#                 -6,
#                 -6
#             ],
#             [
#                 -13,
#                 -7
#             ],
#             [
#                 -14,
#                 -4
#             ],
#             [
#                 -18,
#                 -3
#             ],
#             [
#                 -11,
#                 -4
#             ],
#             [
#                 -8,
#                 -4
#             ],
#             [
#                 -8,
#                 -6
#             ],
#             [
#                 -5,
#                 -5
#             ],
#             [
#                 -5,
#                 -6
#             ],
#             [
#                 -2,
#                 -5
#             ],
#             [
#                 0,
#                 -6
#             ],
#             [
#                 2,
#                 -5
#             ],
#             [
#                 12,
#                 -15
#             ],
#             [
#                 3,
#                 -5
#             ],
#             [
#                 1,
#                 -6
#             ],
#             [
#                 -1,
#                 -14
#             ],
#             [
#                 -3,
#                 -13
#             ]
#         ],
#         [
#             [
#                 6995,
#                 2001
#             ],
#             [
#                 -66,
#                 -12
#             ],
#             [
#                 -16,
#                 -2
#             ],
#             [
#                 -14,
#                 2
#             ],
#             [
#                 -9,
#                 2
#             ],
#             [
#                 -8,
#                 3
#             ],
#             [
#                 -12,
#                 2
#             ],
#             [
#                 -14,
#                 1
#             ],
#             [
#                 -25,
#                 -1
#             ],
#             [
#                 -13,
#                 2
#             ],
#             [
#                 -11,
#                 2
#             ],
#             [
#                 -7,
#                 3
#             ],
#             [
#                 -7,
#                 2
#             ],
#             [
#                 -17,
#                 4
#             ],
#             [
#                 -12,
#                 -1
#             ],
#             [
#                 -14,
#                 -6
#             ],
#             [
#                 -22,
#                 -13
#             ],
#             [
#                 -19,
#                 -20
#             ]
#         ],
#         [
#             [
#                 6709,
#                 1969
#             ],
#             [
#                 -52,
#                 16
#             ],
#             [
#                 -9,
#                 5
#             ],
#             [
#                 -26,
#                 13
#             ],
#             [
#                 -19,
#                 7
#             ],
#             [
#                 -16,
#                 8
#             ],
#             [
#                 -23,
#                 8
#             ],
#             [
#                 -6,
#                 -5
#             ],
#             [
#                 -7,
#                 -9
#             ],
#             [
#                 -5,
#                 -4
#             ],
#             [
#                 -9,
#                 -2
#             ],
#             [
#                 -10,
#                 -1
#             ],
#             [
#                 -13,
#                 1
#             ],
#             [
#                 -9,
#                 0
#             ],
#             [
#                 -8,
#                 -2
#             ],
#             [
#                 -11,
#                 -8
#             ],
#             [
#                 -6,
#                 -3
#             ],
#             [
#                 -8,
#                 -1
# ...
#                         "hc-key": "pe-pa",
#                         "labelrank": "7",
#                         "hc-a2": "PA",
#                         "fips": "PE19",
#                         "type-en": "Department",
#                         "name": "Pasco",
#                         "woe-label": "Pasco, PE, Peru",
#                         "postal-code": "PA",
#                         "country": "Peru",
#                         "latitude": "-10.3457"
#                     },
#                     "id": "PE.PA",
#                     "arcs": [
#                         [
#                             52,
#                             53,
#                             -46,
#                             54
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "San Mart\u00edn",
#                         "hasc": "PE.SM",
#                         "iso": "SAM",
#                         "hc-middle-y": 0.6,
#                         "alt-name": "San Mart",
#                         "hc-middle-x": 0.4,
#                         "woe-id": "2346489",
#                         "longitude": "-76.6238",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40222,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-sm",
#                         "labelrank": "4",
#                         "hc-a2": "SM",
#                         "fips": "PE22",
#                         "type-en": "Department",
#                         "name": "San Mart\u00edn",
#                         "woe-label": "San Martin, PE, Peru",
#                         "postal-code": "SM",
#                         "country": "Peru",
#                         "latitude": "-7.30853"
#                     },
#                     "id": "PE.SM",
#                     "arcs": [
#                         [
#                             -49,
#                             -51,
#                             55,
#                             56
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "Ucayali",
#                         "hasc": "PE.UC",
#                         "iso": "UCA",
#                         "hc-middle-y": 0.79,
#                         "alt-name": null,
#                         "hc-middle-x": 0.59,
#                         "woe-id": "2346492",
#                         "longitude": "-73.24930000000001",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40425,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-uc",
#                         "labelrank": "4",
#                         "hc-a2": "UC",
#                         "fips": "PE25",
#                         "type-en": "Department",
#                         "name": "Ucayali",
#                         "woe-label": "Ucayali, PE, Peru",
#                         "postal-code": "UC",
#                         "country": "Peru",
#                         "latitude": "-9.99816"
#                     },
#                     "id": "PE.UC",
#                     "arcs": [
#                         [
#                             57,
#                             -29,
#                             -27,
#                             58,
#                             -55,
#                             -45,
#                             59
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "Amazonas",
#                         "hasc": "PE.AM",
#                         "iso": "AMA",
#                         "hc-middle-y": 0.48,
#                         "alt-name": null,
#                         "hc-middle-x": 0.38,
#                         "woe-id": "2346468",
#                         "longitude": "-77.9695",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40201,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-am",
#                         "labelrank": "4",
#                         "hc-a2": "AM",
#                         "fips": "PE01",
#                         "type-en": "Department",
#                         "name": "Amazonas",
#                         "woe-label": "Amazonas, PE, Peru",
#                         "postal-code": "AM",
#                         "country": "Peru",
#                         "latitude": "-5.0485"
#                     },
#                     "id": "PE.AM",
#                     "arcs": [
#                         [
#                             -56,
#                             -50,
#                             -43,
#                             60,
#                             61
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "Loreto",
#                         "hasc": "PE.LO",
#                         "iso": "LOR",
#                         "hc-middle-y": 0.48,
#                         "alt-name": null,
#                         "hc-middle-x": 0.38,
#                         "woe-id": "2346483",
#                         "longitude": "-73.88679999999999",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40316,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-lo",
#                         "labelrank": "4",
#                         "hc-a2": "LO",
#                         "fips": "PE16",
#                         "type-en": "Department",
#                         "name": "Loreto",
#                         "woe-label": "Loreto, PE, Peru",
#                         "postal-code": "LO",
#                         "country": "Peru",
#                         "latitude": "-4.27471"
#                     },
#                     "id": "PE.LO",
#                     "arcs": [
#                         [
#                             -60,
#                             -44,
#                             -57,
#                             -62,
#                             62
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "Ayacucho",
#                         "hasc": "PE.AY",
#                         "iso": "AYA",
#                         "hc-middle-y": 0.57,
#                         "alt-name": null,
#                         "hc-middle-x": 0.41,
#                         "woe-id": "2346472",
#                         "longitude": "-73.9838",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40905,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-ay",
#                         "labelrank": "7",
#                         "hc-a2": "AY",
#                         "fips": "PE05",
#                         "type-en": "Department",
#                         "name": "Ayacucho",
#                         "woe-label": "Ayacucho, PE, Peru",
#                         "postal-code": "AY",
#                         "country": "Peru",
#                         "latitude": "-13.9245"
#                     },
#                     "id": "PE.AY",
#                     "arcs": [
#                         [
#                             -25,
#                             -16,
#                             -22,
#                             63,
#                             64,
#                             65
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "Lima Provincia",
#                         "hasc": "PE.LP",
#                         "iso": "LMA",
#                         "hc-middle-y": 0.33,
#                         "alt-name": "Lima Metropolitana",
#                         "hc-middle-x": 0.33,
#                         "woe-id": 28358302,
#                         "longitude": -76.9236,
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40615,
#                         "type": "Distrito Capital",
#                         "region": null,
#                         "hc-key": "pe-lp",
#                         "labelrank": 9,
#                         "hc-a2": "LP",
#                         "fips": "PE26",
#                         "type-en": "Captial District",
#                         "name": "Lima Provincia",
#                         "woe-label": "\u00c1rea Metropolitanan de Lima, PE, Peru",
#                         "postal-code": null,
#                         "country": "Peru",
#                         "latitude": -12.1124
#                     },
#                     "id": "PE.LP",
#                     "arcs": [
#                         [
#                             66,
#                             -3,
#                             67,
#                             68
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "Huancavelica",
#                         "hasc": "PE.HV",
#                         "iso": "HUV",
#                         "hc-middle-y": 0.48,
#                         "alt-name": null,
#                         "hc-middle-x": 0.54,
#                         "woe-id": "2346476",
#                         "longitude": "-75.0416",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40909,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-hv",
#                         "labelrank": "7",
#                         "hc-a2": "HV",
#                         "fips": "PE09",
#                         "type-en": "Department",
#                         "name": "Huancavelica",
#                         "woe-label": "Huancavelica, PE, Peru",
#                         "postal-code": "HV",
#                         "country": "Peru",
#                         "latitude": "-13.0523"
#                     },
#                     "id": "PE.HV",
#                     "arcs": [
#                         [
#                             -65,
#                             69,
#                             70,
#                             71
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "MultiPolygon",
#                     "properties": {
#                         "woe-name": "Ica",
#                         "hasc": "PE.IC",
#                         "iso": "ICA",
#                         "hc-middle-y": 0.52,
#                         "alt-name": null,
#                         "hc-middle-x": 0.49,
#                         "woe-id": "2346478",
#                         "longitude": "-75.6773",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 41011,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-ic",
#                         "labelrank": "7",
#                         "hc-a2": "IC",
#                         "fips": "PE11",
#                         "type-en": "Department",
#                         "name": "Ica",
#                         "woe-label": "Ica, PE, Peru",
#                         "postal-code": "IC",
#                         "country": "Peru",
#                         "latitude": "-14.2257"
#                     },
#                     "id": "PE.IC",
#                     "arcs": [
#                         [
#                             [
#                                 72
#                             ]
#                         ],
#                         [
#                             [
#                                 73
#                             ]
#                         ],
#                         [
#                             [
#                                 -64,
#                                 -21,
#                                 74,
#                                 75,
#                                 -70
#                             ]
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "Jun\u00edn",
#                         "hasc": "PE.JU",
#                         "iso": "JUN",
#                         "hc-middle-y": 0.43,
#                         "alt-name": "Junnn",
#                         "hc-middle-x": 0.53,
#                         "woe-id": "2346479",
#                         "longitude": "-74.96420000000001",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40712,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-ju",
#                         "labelrank": "4",
#                         "hc-a2": "JU",
#                         "fips": "PE12",
#                         "type-en": "Department",
#                         "name": "Jun\u00edn",
#                         "woe-label": "Jun\u00edn, PE, Peru",
#                         "postal-code": "JU",
#                         "country": "Peru",
#                         "latitude": "-11.3744"
#                     },
#                     "id": "PE.JU",
#                     "arcs": [
#                         [
#                             -59,
#                             -26,
#                             -66,
#                             -72,
#                             76,
#                             -53
#                         ]
#                     ]
#                 },
#                 {
#                     "type": "Polygon",
#                     "properties": {
#                         "woe-name": "Lima",
#                         "hasc": "PE.LR",
#                         "iso": "LIM",
#                         "hc-middle-y": 0.37,
#                         "alt-name": "Lima province",
#                         "hc-middle-x": 0.39,
#                         "woe-id": "2346482",
#                         "longitude": "-77.07559999999999",
#                         "subregion": null,
#                         "hc-group": "admin1",
#                         "nute": 40615,
#                         "type": "Departamento",
#                         "region": null,
#                         "hc-key": "pe-lr",
#                         "labelrank": "4",
#                         "hc-a2": "LR",
#                         "fips": "PE15",
#                         "type-en": "Department",
#                         "name": "Lima",
#                         "woe-label": "Lima, PE, Peru",
#                         "postal-code": "LR",
#                         "country": "Peru",
#                         "latitude": "-11.0602"
#                     },
#                     "id": "PE.LR",
#                     "arcs": [
#                         [
#                             -54,
#                             -77,
#                             -71,
#                             -76,
#                             77,
#                             -69,
#                             78,
#                             -38,
#                             -47
#                         ]
#                     ]
#                 }
#             ]
#         }
#     }
# }
